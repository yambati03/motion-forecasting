# %%
import numpy as np
import pickle
import os

import torch
from torch import nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
run_local = True # change to False if using google drive
from enum import Enum

if run_local: # place pickle file in same directory as this ipynb
    data_path = os.path.join(os.getcwd(), "parsed_data", "parsed_data_final_srishti.pkl")
    with open(data_path, "rb") as file:
        data = pickle.load(file)
else:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/MyDrive/CS7643Group/Dataset/parsed_data_final_srishti.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)

print(f"Shape of full dataset: {data.shape}")
data = data[:, :-1, :]


class FeatureOption(Enum):
    VEHICLE_ONLY = 1 # Vehicle features only
    VEHICLE_AND_PEDESTRIAN = 2 # Vehicle and Pedestrian features:
    VEHICLE_PEDESTRIAN_ROADGRAPH = 3 # Vehicle and Pedestrian and Roadgraph features:
    VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE = 4 # Vehicle and Pedestrian and Roadgraph and Bicycle features

feature_option = FeatureOption.VEHICLE_AND_PEDESTRIAN # choose from: VEHICLE_ONLY, VEHICLE_AND_PEDESTRIAN, VEHICLE_PEDESTRIAN_ROADGRAPH, VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE

if feature_option == FeatureOption.VEHICLE_ONLY: # Vehicle Only
    data = data[:, :, 1:6]
elif feature_option == FeatureOption.VEHICLE_AND_PEDESTRIAN: # Vehicle and pedestrian
    data = data[:, :, 1:8]
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH: # Vehicle, pedestrian, and roadgraph 
    vehicle_pedestrian = data[:, :, 1:8]
    roadgraph = data[:, :, 10:]
    data = np.concatenate((vehicle_pedestrian, roadgraph), axis = 2)
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE: # vehicle, pedestrian, roadgraph and bicycle
    data = data[:, :, 1:]
else:
    raise Exception("Invalid Choice")


first_set = data[:, :, :-2]
last_two_values = data[:, :, -2:]

# Compute min and max for the last two features
min_val_last_two = last_two_values.min(axis=(0, 1), keepdims=True)  # Shape: (1, 1, 2)
max_val_last_two = last_two_values.max(axis=(0, 1), keepdims=True)  # Shape: (1, 1, 2)

# Normalize the last two values using their specific min and max
normalized_last_two = (last_two_values - min_val_last_two) / (max_val_last_two - min_val_last_two + 1e-8)

# Update the data with normalized last two features
data[:, :, -2:] = normalized_last_two


X_train = data[:int(0.8*len(data)), :80, :]
X_val = data[int(0.8*len(data)): , :80, :]

y_train = data[:int(0.8*len(data)), 80:, :]
y_val = data[int(0.8*len(data)): , 80:, :]

print("For each input state: X position, Y position, X velocity, Y velocity, Heading")
print("For each output state: X velocity, Y velocity")
print("Feature Type: ", feature_option)
print("\nTraining Data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")

print("\nValidation Data:") 
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Shape of full dataset: (2933, 91, 14)
# For each input state: X position, Y position, X velocity, Y velocity, Heading
# For each output state: X velocity, Y velocity
# Feature Type:  FeatureOption.VEHICLE_AND_PEDESTRIAN
#
# Training Data:
# X_train shape: (2346, 80, 7)
# y_train shape: (2346, 10, 7)
#
# Validation Data:
# X_val shape: (587, 80, 7)
# y_val shape: (587, 10, 7)

# %%
import torch
import torch.nn as nn

class TrajectoryTransformer(nn.Module):
    def __init__(self, input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10, max_seq_length=100):
        super(TrajectoryTransformer, self).__init__()
        self.embedding = nn.Linear(input_size, model_dim)
        self.positional_encoding = nn.Parameter(torch.randn(max_seq_length, model_dim))
        self.transformer = nn.Transformer(
            d_model=model_dim,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            num_decoder_layers=num_layers,
            dim_feedforward=4 * model_dim,
            dropout=0.5 #dropout=0.1
        )
        self.fc = nn.Linear(model_dim, output_features * output_timesteps)
        self.output_features = output_features
        self.output_timesteps = output_timesteps

    def forward(self, x):
        # x: (batch_size, seq_length, input_size)
        batch_size, seq_length, input_size = x.size()
        src = self.embedding(x) + self.positional_encoding[:seq_length]  # Add positional encoding
        src = src.permute(1, 0, 2)  # Transformer expects (seq_len, batch_size, model_dim)

        tgt = torch.zeros_like(src)  # Dummy target (for autoregressive tasks, replace with actual decoder inputs if needed)

        # Pass through the Transformer
        output = self.transformer(src, tgt)
        output = output[-1]  # Take the last sequence position
        output = self.fc(output)
        return output.view(-1, self.output_timesteps, self.output_features)  # Reshape to (batch_size, 10, 2)

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from loss_functions import get_loss_function

# Initialize lists to store loss history
train_losses = []
val_losses = []

def train_model(model, train_loader, val_loader, num_epochs=10, initial_lr=0.001, T_max=10, loss_fn=nn.MSELoss()):
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

    best_val_loss = float('inf')
    model_save_path = "transformer_external_model.pth"  # Save path for the best model

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        epoch_train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")

            optimizer.zero_grad()
            predictions = model(batch_x)
            # print(predictions.shape)
            loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_train_loss += loss.item()

        scheduler.step()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}')

        # Validation loop
        model.eval()
        epoch_val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
                predictions = model(batch_x)
                loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
                epoch_val_loss += loss.item()

            avg_val_loss = epoch_val_loss / len(val_loader)
            val_losses.append(avg_val_loss)
            print(f'Validation Loss: {avg_val_loss:.4f}')

            # Save the model if it has the best validation loss (Comment out if you don't want to save)
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(model.state_dict(), model_save_path)
                print(f"Saved best model with validation loss: {best_val_loss:.4f}")

    print(f"Training complete. Best validation loss: {best_val_loss:.4f}. Model saved to {model_save_path}.")


train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
# Mess with batch size here
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)


input_size = X_train.shape[2]
# print(input_size)
hidden_size = 64 # changeable
input_size = X_train.shape[2]

model_dim = 16  # Adjustable
num_heads = 1  # Adjustable
num_layers = 1  # Adjustable

model = TrajectoryTransformer(input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10).to("cuda")

loss_weights = { # Update weights of different loss terms 
    "position_loss": 1.0,
    "velocity_loss": 0.5,
    "smoothness_loss": 0.25,
    "terminal_loss": 2.0,
    "delta_loss": 0.5
}
# Customize loss function here (Everything is True/False except time_weighting_scheme)
loss_fn = get_loss_function(
    "trajectory_loss", # trajectory_loss is just position loss if everything else is False
    use_velocity_loss=True,
    use_smoothness_loss=True,
    use_terminal_loss=True,
    time_weighting_scheme='Exponential',  #None, Linear, Exponential
    use_delta_loss=True,
    use_magnitude_loss=False, # Only consider heading in delta loss
    prediction_horizon=10, # change to match predicted timesteps (used for time)
    loss_weights=loss_weights # defaults to ALL = 1.0 if not included
) # Add more lines as new loss functions are added

# mess with epochs, initial_lr and T_max here
train_model(model, train_loader, val_loader, num_epochs=100, initial_lr=1e-2, T_max=100, loss_fn=loss_fn)
# Out:
# /home/yashas/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch [1/100], Training Loss: 26960.7002, LR: 0.009998
# Validation Loss: 13301.0612
# Saved best model with validation loss: 13301.0612
# Epoch [2/100], Training Loss: 26125.5530, LR: 0.009990
# Validation Loss: 12896.9870
# Saved best model with validation loss: 12896.9870
# Epoch [3/100], Training Loss: 25466.1041, LR: 0.009978
# Validation Loss: 12735.7300
# Saved best model with validation loss: 12735.7300
# Epoch [4/100], Training Loss: 25201.3662, LR: 0.009961
# Validation Loss: 12629.0885
# Saved best model with validation loss: 12629.0885
# Epoch [5/100], Training Loss: 25097.2341, LR: 0.009938
# Validation Loss: 12174.1706
# Saved best model with validation loss: 12174.1706
# Epoch [6/100], Training Loss: 24413.1909, LR: 0.009911
# Validation Loss: 11928.4265
# Saved best model with validation loss: 11928.4265
# Epoch [7/100], Training Loss: 23964.6178, LR: 0.009880
# Validation Loss: 11962.2697
# Epoch [8/100], Training Loss: 23610.2541, LR: 0.009843
# Validation Loss: 12020.6837
# Epoch [9/100], Training Loss: 23422.2008, LR: 0.009801
# Validation Loss: 11922.2322
# Saved best model with validation loss: 11922.2322
# Epoch [10/100], Training Loss: 23096.1266, LR: 0.009755
# Validation Loss: 11700.0124
# Saved best model with validation loss: 11700.0124
# Epoch [11/100], Training Loss: 23307.5813, LR: 0.009704
# Validation Loss: 11325.1731
# Saved best model with validation loss: 11325.1731
# Epoch [12/100], Training Loss: 23178.5893, LR: 0.009649
# Validation Loss: 11555.4917
# Epoch [13/100], Training Loss: 22750.2026, LR: 0.009589
# Validation Loss: 11776.0071
# Epoch [14/100], Training Loss: 22630.9952, LR: 0.009524
# Validation Loss: 11987.4368
# Epoch [15/100], Training Loss: 22804.6814, LR: 0.009455
# Validation Loss: 12052.9623
# Epoch [16/100], Training Loss: 22524.1811, LR: 0.009382
# Validation Loss: 11804.4434
# Epoch [17/100], Training Loss: 22404.5449, LR: 0.009304
# Validation Loss: 11693.7809
# Epoch [18/100], Training Loss: 22631.6799, LR: 0.009222
# Validation Loss: 11710.6831
# Epoch [19/100], Training Loss: 22294.9977, LR: 0.009135
# Validation Loss: 12173.8206
# Epoch [20/100], Training Loss: 22472.1747, LR: 0.009045
# Validation Loss: 11236.3816
# Saved best model with validation loss: 11236.3816
# Epoch [21/100], Training Loss: 22478.2645, LR: 0.008951
# Validation Loss: 11770.1391
# Epoch [22/100], Training Loss: 22321.2889, LR: 0.008853
# Validation Loss: 11741.0595
# Epoch [23/100], Training Loss: 22522.7456, LR: 0.008751
# Validation Loss: 11232.6575
# Saved best model with validation loss: 11232.6575
# Epoch [24/100], Training Loss: 22390.0905, LR: 0.008645
# Validation Loss: 11406.9621
# Epoch [25/100], Training Loss: 22454.1138, LR: 0.008536
# Validation Loss: 11236.4883
# Epoch [26/100], Training Loss: 22146.6743, LR: 0.008423
# Validation Loss: 11521.9576
# Epoch [27/100], Training Loss: 22486.0951, LR: 0.008307
# Validation Loss: 11319.8166
# Epoch [28/100], Training Loss: 22230.3881, LR: 0.008187
# Validation Loss: 11411.8657
# Epoch [29/100], Training Loss: 22261.9028, LR: 0.008065
# Validation Loss: 11676.9064
# Epoch [30/100], Training Loss: 22130.2597, LR: 0.007939
# Validation Loss: 11391.6689
# Epoch [31/100], Training Loss: 22112.2721, LR: 0.007810
# Validation Loss: 11234.1557
# Epoch [32/100], Training Loss: 22055.0226, LR: 0.007679
# Validation Loss: 11246.0026
# Epoch [33/100], Training Loss: 22058.8539, LR: 0.007545
# Validation Loss: 11358.4497
# Epoch [34/100], Training Loss: 22168.9140, LR: 0.007409
# Validation Loss: 11619.6589
# Epoch [35/100], Training Loss: 22124.8434, LR: 0.007270
# Validation Loss: 11387.7706
# Epoch [36/100], Training Loss: 21990.1050, LR: 0.007129
# Validation Loss: 11297.7581
# Epoch [37/100], Training Loss: 22094.0064, LR: 0.006986
# Validation Loss: 11517.0788
# Epoch [38/100], Training Loss: 22107.2143, LR: 0.006841
# Validation Loss: 11383.0427
# Epoch [39/100], Training Loss: 22017.2034, LR: 0.006694
# Validation Loss: 11557.0437
# Epoch [40/100], Training Loss: 21889.0792, LR: 0.006545
# Validation Loss: 11511.5198
# Epoch [41/100], Training Loss: 22221.4251, LR: 0.006395
# Validation Loss: 11510.0552
# Epoch [42/100], Training Loss: 22284.0635, LR: 0.006243
# Validation Loss: 11397.5501
# Epoch [43/100], Training Loss: 22041.2269, LR: 0.006091
# Validation Loss: 11718.9476
# Epoch [44/100], Training Loss: 22090.8849, LR: 0.005937
# Validation Loss: 11414.6190
# Epoch [45/100], Training Loss: 22002.7171, LR: 0.005782
# Validation Loss: 11331.5403
# Epoch [46/100], Training Loss: 21831.3252, LR: 0.005627
# Validation Loss: 11209.7027
# Saved best model with validation loss: 11209.7027
# Epoch [47/100], Training Loss: 21908.2998, LR: 0.005471
# Validation Loss: 11238.4373
# Epoch [48/100], Training Loss: 22138.0053, LR: 0.005314
# Validation Loss: 11334.4985
# Epoch [49/100], Training Loss: 22111.4314, LR: 0.005157
# Validation Loss: 11239.5904
# Epoch [50/100], Training Loss: 21963.3106, LR: 0.005000
# Validation Loss: 11565.8999
# Epoch [51/100], Training Loss: 22212.0254, LR: 0.004843
# Validation Loss: 11463.0595
# Epoch [52/100], Training Loss: 21905.9174, LR: 0.004686
# Validation Loss: 11286.4655
# Epoch [53/100], Training Loss: 21956.8385, LR: 0.004529
# Validation Loss: 11243.6734
# Epoch [54/100], Training Loss: 21950.3304, LR: 0.004373
# Validation Loss: 11484.9470
# Epoch [55/100], Training Loss: 22129.3053, LR: 0.004218
# Validation Loss: 11643.5131
# Epoch [56/100], Training Loss: 22209.8768, LR: 0.004063
# Validation Loss: 11260.0384
# Epoch [57/100], Training Loss: 21996.5151, LR: 0.003909
# Validation Loss: 11180.8950
# Saved best model with validation loss: 11180.8950
# Epoch [58/100], Training Loss: 21923.2083, LR: 0.003757
# Validation Loss: 11701.8435
# Epoch [59/100], Training Loss: 21927.8654, LR: 0.003605
# Validation Loss: 11337.3927
# Epoch [60/100], Training Loss: 22027.7089, LR: 0.003455
# Validation Loss: 11539.2690
# Epoch [61/100], Training Loss: 21724.9553, LR: 0.003306
# Validation Loss: 11259.0142
# Epoch [62/100], Training Loss: 21863.2703, LR: 0.003159
# Validation Loss: 11391.3462
# Epoch [63/100], Training Loss: 21884.5266, LR: 0.003014
# Validation Loss: 11212.2028
# Epoch [64/100], Training Loss: 21818.6768, LR: 0.002871
# Validation Loss: 11479.2240
# Epoch [65/100], Training Loss: 21933.6447, LR: 0.002730
# Validation Loss: 11248.7381
# Epoch [66/100], Training Loss: 21840.3808, LR: 0.002591
# Validation Loss: 11279.8740
# Epoch [67/100], Training Loss: 22003.1947, LR: 0.002455
# Validation Loss: 11358.4789
# Epoch [68/100], Training Loss: 21781.4576, LR: 0.002321
# Validation Loss: 11155.0892
# Saved best model with validation loss: 11155.0892
# Epoch [69/100], Training Loss: 21829.9422, LR: 0.002190
# Validation Loss: 11158.0290
# Epoch [70/100], Training Loss: 21743.4392, LR: 0.002061
# Validation Loss: 11161.2115
# Epoch [71/100], Training Loss: 21918.1896, LR: 0.001935
# Validation Loss: 11322.3519
# Epoch [72/100], Training Loss: 21789.4513, LR: 0.001813
# Validation Loss: 11180.7119
# Epoch [73/100], Training Loss: 21867.1320, LR: 0.001693
# Validation Loss: 11174.5166
# Epoch [74/100], Training Loss: 21855.8244, LR: 0.001577
# Validation Loss: 11241.4370
# Epoch [75/100], Training Loss: 21698.7615, LR: 0.001464
# Validation Loss: 11248.9690
# Epoch [76/100], Training Loss: 21878.9226, LR: 0.001355
# Validation Loss: 11260.6731
# Epoch [77/100], Training Loss: 21767.1593, LR: 0.001249
# Validation Loss: 11284.8210
# Epoch [78/100], Training Loss: 21792.6725, LR: 0.001147
# Validation Loss: 11340.1173
# Epoch [79/100], Training Loss: 21992.4714, LR: 0.001049
# Validation Loss: 11308.4575
# Epoch [80/100], Training Loss: 21842.5895, LR: 0.000955
# Validation Loss: 11161.2938
# Epoch [81/100], Training Loss: 21715.7171, LR: 0.000865
# Validation Loss: 11122.3403
# Saved best model with validation loss: 11122.3403
# Epoch [82/100], Training Loss: 21796.5326, LR: 0.000778
# Validation Loss: 11132.8157
# Epoch [83/100], Training Loss: 21761.8306, LR: 0.000696
# Validation Loss: 11107.5382
# Saved best model with validation loss: 11107.5382
# Epoch [84/100], Training Loss: 21678.9287, LR: 0.000618
# Validation Loss: 11200.2982
# Epoch [85/100], Training Loss: 22043.6929, LR: 0.000545
# Validation Loss: 11110.1097
# Epoch [86/100], Training Loss: 21689.1190, LR: 0.000476
# Validation Loss: 11133.3131
# Epoch [87/100], Training Loss: 21701.7772, LR: 0.000411
# Validation Loss: 11138.8467
# Epoch [88/100], Training Loss: 21732.9822, LR: 0.000351
# Validation Loss: 11152.3413
# Epoch [89/100], Training Loss: 21859.5681, LR: 0.000296
# Validation Loss: 11139.6803
# Epoch [90/100], Training Loss: 21768.0811, LR: 0.000245
# Validation Loss: 11118.1098
# Epoch [91/100], Training Loss: 21664.0281, LR: 0.000199
# Validation Loss: 11106.8294
# Saved best model with validation loss: 11106.8294
# Epoch [92/100], Training Loss: 21752.8085, LR: 0.000157
# Validation Loss: 11129.9429
# Epoch [93/100], Training Loss: 21725.7497, LR: 0.000120
# Validation Loss: 11150.9132
# Epoch [94/100], Training Loss: 21718.4892, LR: 0.000089
# Validation Loss: 11115.6416
# Epoch [95/100], Training Loss: 21859.3124, LR: 0.000062
# Validation Loss: 11107.0080
# Epoch [96/100], Training Loss: 21697.2168, LR: 0.000039
# Validation Loss: 11119.6710
# Epoch [97/100], Training Loss: 21584.1713, LR: 0.000022
# Validation Loss: 11112.9587
# Epoch [98/100], Training Loss: 21683.8932, LR: 0.000010
# Validation Loss: 11111.4912
# Epoch [99/100], Training Loss: 21758.7091, LR: 0.000002
# Validation Loss: 11110.9937
# Epoch [100/100], Training Loss: 21599.0030, LR: 0.000000
# Validation Loss: 11111.1530
# Training complete. Best validation loss: 11106.8294. Model saved to transformer_external_model.pth.

# %%
def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss_curves(train_losses, val_losses)

# %%
from metrics import (
    compute_predicted_positions,
    compute_mean_ade,
    compute_fde,
    compute_directional_accuracy,
    compute_linear_wade,
    compute_exponential_wade
) # add new imports here as new metrics created

x = torch.tensor(X_val, dtype=torch.float32).to("cuda")
y = torch.tensor(y_val, dtype=torch.float32).to("cuda")
# Compute metrics
with torch.no_grad():
    pred_position = compute_predicted_positions(model, x, y)
    mean_ade = compute_mean_ade(pred_position, y)
    fde = compute_fde(pred_position, y)
    directional_accuracy = compute_directional_accuracy(pred_position, y)
    l_wade = compute_linear_wade(pred_position, y)
    
    alpha = 0.5 #Smaller alpha -> more uniform weights, larger alpha -> more emphasis on earlier timesteps (defaults to 0.1)
    e_wade = compute_exponential_wade(pred_position, y, alpha=alpha) 

print(f"Mean Average Displacement Error (MADE): {mean_ade:.4f}")
print(f"Final Displacement Error (FDE): {fde:.4f}")
print(f"Directional Accuracy (DA): {directional_accuracy:.4f}")
print(f"Linear Weighted Average Displacement Error (LWADE): {l_wade:.4f}")
print(f"Exponential Weighted Average Displacement Error (EWADE) with alpha={alpha}: {e_wade:.4f}")
print(f"Overall Score (Lower is better) = {e_wade + 0.5 * fde - 0.5 * directional_accuracy}")
# Out:
# Mean Average Displacement Error (MADE): 3.7374
# Final Displacement Error (FDE): 8.1464
# Directional Accuracy (DA): 0.3648
# Linear Weighted Average Displacement Error (LWADE): 0.2595
# Exponential Weighted Average Displacement Error (EWADE) with alpha=0.5: 0.1639
# Overall Score (Lower is better) = 4.0547527223825455

# %%
# Example 400 - straight path towards top right
example_index = 400
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 369 - very slight curve
example_index = 369
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 411 - straight path towards bottom left
example_index = 411
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 31 - No movement
example_index = 31
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 291 - Sharp turn
example_index = 291
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 370 - Smooth slight turn
example_index = 370
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 77 - smooth 90 degree turn
example_index = 77
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()
