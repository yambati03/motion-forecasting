# %%
import numpy as np
import pickle
import os

import torch
from torch import nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
run_local = True # change to False if using google drive
from enum import Enum

if run_local: # place pickle file in same directory as this ipynb
    data_path = os.path.join(os.getcwd(), "parsed_data", "parsed_data_final.pkl")
    with open(data_path, "rb") as file:
        data = pickle.load(file)
else:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/MyDrive/CS7643Group/Dataset/parsed_data_final_srishti.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)

print(f"Shape of full dataset: {data.shape}")
data = data[:, :-1, :]


class FeatureOption(Enum):
    VEHICLE_ONLY = 1 # Vehicle features only
    VEHICLE_AND_PEDESTRIAN = 2 # Vehicle and Pedestrian features:
    VEHICLE_PEDESTRIAN_ROADGRAPH = 3 # Vehicle and Pedestrian and Roadgraph features:
    VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE = 4 # Vehicle and Pedestrian and Roadgraph and Bicycle features

feature_option = FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE # choose from: VEHICLE_ONLY, VEHICLE_AND_PEDESTRIAN, VEHICLE_PEDESTRIAN_ROADGRAPH, VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE

if feature_option == FeatureOption.VEHICLE_ONLY: # Vehicle Only
    data = data[:, :, 1:6]
elif feature_option == FeatureOption.VEHICLE_AND_PEDESTRIAN: # Vehicle and pedestrian
    data = data[:, :, 1:8]
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH: # Vehicle, pedestrian, and roadgraph 
    vehicle_pedestrian = data[:, :, 1:8]
    roadgraph = data[:, :, 10:]
    data = np.concatenate((vehicle_pedestrian, roadgraph), axis = 2)
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE: # vehicle, pedestrian, roadgraph and bicycle
    data = data[:, :, 1:]
else:
    raise Exception("Invalid Choice")


first_set = data[:, :, :-2]
last_two_values = data[:, :, -2:]

# Compute min and max for the last two features
min_val_last_two = last_two_values.min(axis=(0, 1), keepdims=True)  # Shape: (1, 1, 2)
max_val_last_two = last_two_values.max(axis=(0, 1), keepdims=True)  # Shape: (1, 1, 2)

# Normalize the last two values using their specific min and max
normalized_last_two = (last_two_values - min_val_last_two) / (max_val_last_two - min_val_last_two + 1e-8)

# Update the data with normalized last two features
data[:, :, -2:] = normalized_last_two


X_train = data[:int(0.8*len(data)), :80, :]
X_val = data[int(0.8*len(data)): , :80, :]

y_train = data[:int(0.8*len(data)), 80:, :]
y_val = data[int(0.8*len(data)): , 80:, :]

print("For each input state: X position, Y position, X velocity, Y velocity, Heading")
print("For each output state: X velocity, Y velocity")
print("Feature Type: ", feature_option)
print("\nTraining Data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")

print("\nValidation Data:") 
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Shape of full dataset: (2933, 91, 14)
# For each input state: X position, Y position, X velocity, Y velocity, Heading
# For each output state: X velocity, Y velocity
# Feature Type:  FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE
#
# Training Data:
# X_train shape: (2346, 80, 13)
# y_train shape: (2346, 10, 13)
#
# Validation Data:
# X_val shape: (587, 80, 13)
# y_val shape: (587, 10, 13)

# %%
import torch
import torch.nn as nn

class TrajectoryTransformer(nn.Module):
    def __init__(self, input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10, max_seq_length=100):
        super(TrajectoryTransformer, self).__init__()
        self.embedding = nn.Linear(input_size, model_dim)
        self.positional_encoding = nn.Parameter(torch.randn(max_seq_length, model_dim))
        self.layer_norm = nn.LayerNorm(model_dim)
        self.transformer = nn.Transformer(
            d_model=model_dim,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            num_decoder_layers=num_layers,
            dim_feedforward=4 * model_dim,
            dropout=0.5 #dropout=0.1
        )
        self.fc = nn.Linear(model_dim, output_features * output_timesteps)
        self.output_features = output_features
        self.output_timesteps = output_timesteps

    def forward(self, x):
        # x: (batch_size, seq_length, input_size)
        batch_size, seq_length, input_size = x.size()
        src = self.embedding(x) + self.positional_encoding[:seq_length]  # Add positional encoding
        src = src.permute(1, 0, 2)  # Transformer expects (seq_len, batch_size, model_dim)
        src = self.layer_norm(src)

        tgt = torch.zeros_like(src)  # Dummy target (for autoregressive tasks, replace with actual decoder inputs if needed)

        # Pass through the Transformer
        output = self.transformer(src, tgt)
        output = output[-1]  # Take the last sequence position
        output = self.fc(output)
        return output.view(-1, self.output_timesteps, self.output_features)  # Reshape to (batch_size, 10, 2)

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from lib.loss_functions import get_loss_function

# Initialize lists to store loss history
train_losses = []
val_losses = []

def train_model(model, train_loader, val_loader, num_epochs=10, initial_lr=0.001, T_max=10, loss_fn=nn.MSELoss()):
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

    best_val_loss = float('inf')
    model_save_path = "transformer_external_model.pth"  # Save path for the best model

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        epoch_train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")

            optimizer.zero_grad()
            predictions = model(batch_x)
            # print(predictions.shape)
            loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
            optimizer.step()

            epoch_train_loss += loss.item()

        scheduler.step()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}')

        # Validation loop
        model.eval()
        epoch_val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
                predictions = model(batch_x)
                loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
                epoch_val_loss += loss.item()

            avg_val_loss = epoch_val_loss / len(val_loader)
            val_losses.append(avg_val_loss)
            print(f'Validation Loss: {avg_val_loss:.4f}')

            # Save the model if it has the best validation loss (Comment out if you don't want to save)
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(model.state_dict(), model_save_path)
                print(f"Saved best model with validation loss: {best_val_loss:.4f}")

    print(f"Training complete. Best validation loss: {best_val_loss:.4f}. Model saved to {model_save_path}.")


train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
# Mess with batch size here
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)


input_size = X_train.shape[2]
# print(input_size)
hidden_size = 64 # changeable
input_size = X_train.shape[2]

model_dim = 16  # Adjustable
num_heads = 1  # Adjustable
num_layers = 1  # Adjustable

model = TrajectoryTransformer(input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10).to("cuda")

loss_weights = { # Update weights of different loss terms 
    "position_loss": 1.0,
    "velocity_loss": 0.5,
    "smoothness_loss": 0.25,
    "terminal_loss": 2.0,
    "delta_loss": 0.5
}
# Customize loss function here (Everything is True/False except time_weighting_scheme)
loss_fn = get_loss_function(
    "trajectory_loss", # trajectory_loss is just position loss if everything else is False
    use_velocity_loss=True,
    use_smoothness_loss=False,
    use_terminal_loss=False,
    time_weighting_scheme='None',  #None, Linear, Exponential
    use_delta_loss=False,
    use_magnitude_loss=False, # Only consider heading in delta loss
    prediction_horizon=10, # change to match predicted timesteps (used for time)
    loss_weights=loss_weights # defaults to ALL = 1.0 if not included
) # Add more lines as new loss functions are added

# mess with epochs, initial_lr and T_max here
train_model(model, train_loader, val_loader, num_epochs=100, initial_lr=1e-2, T_max=100, loss_fn=loss_fn)
# Out:
# /home/yashas/.local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch [1/100], Training Loss: 1184.1546, LR: 0.009998
# Validation Loss: 598.0077
# Saved best model with validation loss: 598.0077
# Epoch [2/100], Training Loss: 1175.5901, LR: 0.009990
# Validation Loss: 599.2120
# Epoch [3/100], Training Loss: 1180.5770, LR: 0.009978
# Validation Loss: 603.2029
# Epoch [4/100], Training Loss: 1173.4980, LR: 0.009961
# Validation Loss: 609.7218
# Epoch [5/100], Training Loss: 1179.2152, LR: 0.009938
# Validation Loss: 606.4559
# Epoch [6/100], Training Loss: 1182.4536, LR: 0.009911
# Validation Loss: 615.1665
# Epoch [7/100], Training Loss: 1171.6025, LR: 0.009880
# Validation Loss: 612.4913
# Epoch [8/100], Training Loss: 1179.3692, LR: 0.009843
# Validation Loss: 614.9710
# Epoch [9/100], Training Loss: 1183.8738, LR: 0.009801
# Validation Loss: 596.9792
# Saved best model with validation loss: 596.9792
# Epoch [10/100], Training Loss: 1173.5002, LR: 0.009755
# Validation Loss: 607.5180
# Epoch [11/100], Training Loss: 1170.6452, LR: 0.009704
# Validation Loss: 617.1307
# Epoch [12/100], Training Loss: 1181.3334, LR: 0.009649
# Validation Loss: 612.1148
# Epoch [13/100], Training Loss: 1176.0925, LR: 0.009589
# Validation Loss: 611.0465
# Epoch [14/100], Training Loss: 1180.4897, LR: 0.009524
# Validation Loss: 612.3839
# Epoch [15/100], Training Loss: 1170.4931, LR: 0.009455
# Validation Loss: 620.2645
# Epoch [16/100], Training Loss: 1175.2648, LR: 0.009382
# Validation Loss: 635.4380
# Epoch [17/100], Training Loss: 1192.7599, LR: 0.009304
# Validation Loss: 616.1751
# Epoch [18/100], Training Loss: 1175.7094, LR: 0.009222
# Validation Loss: 618.3820
# Epoch [19/100], Training Loss: 1173.4002, LR: 0.009135
# Validation Loss: 621.0997
# Epoch [20/100], Training Loss: 1181.7712, LR: 0.009045
# Validation Loss: 625.6841
# Epoch [21/100], Training Loss: 1176.2426, LR: 0.008951
# Validation Loss: 623.2622
# Epoch [22/100], Training Loss: 1178.6751, LR: 0.008853
# Validation Loss: 614.7404
# Epoch [23/100], Training Loss: 1181.7580, LR: 0.008751
# Validation Loss: 613.3676
# Epoch [24/100], Training Loss: 1183.7874, LR: 0.008645
# Validation Loss: 610.7036
# Epoch [25/100], Training Loss: 1187.2405, LR: 0.008536
# Validation Loss: 610.5593
# Epoch [26/100], Training Loss: 1176.6912, LR: 0.008423
# Validation Loss: 611.8954
# Epoch [27/100], Training Loss: 1180.2499, LR: 0.008307
# Validation Loss: 596.9968
# Epoch [28/100], Training Loss: 1188.1365, LR: 0.008187
# Validation Loss: 597.3442
# Epoch [29/100], Training Loss: 1185.8316, LR: 0.008065
# Validation Loss: 598.0209
# Epoch [30/100], Training Loss: 1179.4921, LR: 0.007939
# Validation Loss: 597.2041
# Epoch [31/100], Training Loss: 1181.0639, LR: 0.007810
# Validation Loss: 597.1102
# Epoch [32/100], Training Loss: 1182.7385, LR: 0.007679
# Validation Loss: 596.5869
# Saved best model with validation loss: 596.5869
# Epoch [33/100], Training Loss: 1175.1824, LR: 0.007545
# Validation Loss: 596.9708
# Epoch [34/100], Training Loss: 1182.4367, LR: 0.007409
# Validation Loss: 597.3053
# Epoch [35/100], Training Loss: 1176.6464, LR: 0.007270
# Validation Loss: 596.0918
# Saved best model with validation loss: 596.0918
# Epoch [36/100], Training Loss: 1179.7900, LR: 0.007129
# Validation Loss: 596.9197
# Epoch [37/100], Training Loss: 1179.3568, LR: 0.006986
# Validation Loss: 597.4934
# Epoch [38/100], Training Loss: 1188.1826, LR: 0.006841
# Validation Loss: 597.5400
# Epoch [39/100], Training Loss: 1184.4636, LR: 0.006694
# Validation Loss: 597.1066
# Epoch [40/100], Training Loss: 1186.8113, LR: 0.006545
# Validation Loss: 597.3504
# Epoch [41/100], Training Loss: 1180.5574, LR: 0.006395
# Validation Loss: 597.2792
# Epoch [42/100], Training Loss: 1182.3717, LR: 0.006243
# Validation Loss: 597.4151
# Epoch [43/100], Training Loss: 1177.7731, LR: 0.006091
# Validation Loss: 597.4754
# Epoch [44/100], Training Loss: 1184.6753, LR: 0.005937
# Validation Loss: 597.8206
# Epoch [45/100], Training Loss: 1177.5477, LR: 0.005782
# Validation Loss: 597.7841
# Epoch [46/100], Training Loss: 1185.7647, LR: 0.005627
# Validation Loss: 597.5762
# Epoch [47/100], Training Loss: 1192.2789, LR: 0.005471
# Validation Loss: 597.3891
# Epoch [48/100], Training Loss: 1174.9030, LR: 0.005314
# Validation Loss: 597.5878
# Epoch [49/100], Training Loss: 1172.7798, LR: 0.005157
# Validation Loss: 597.5405
# Epoch [50/100], Training Loss: 1177.2793, LR: 0.005000
# Validation Loss: 597.5616
# Epoch [51/100], Training Loss: 1183.2517, LR: 0.004843
# Validation Loss: 597.5211
# Epoch [52/100], Training Loss: 1191.2578, LR: 0.004686
# Validation Loss: 597.8694
# Epoch [53/100], Training Loss: 1175.6554, LR: 0.004529
# Validation Loss: 597.8310
# Epoch [54/100], Training Loss: 1177.0006, LR: 0.004373
# Validation Loss: 597.6228
# Epoch [55/100], Training Loss: 1177.2665, LR: 0.004218
# Validation Loss: 597.5924
# Epoch [56/100], Training Loss: 1175.3716, LR: 0.004063
# Validation Loss: 597.7552
# Epoch [57/100], Training Loss: 1184.5755, LR: 0.003909
# Validation Loss: 597.6256
# Epoch [58/100], Training Loss: 1184.4297, LR: 0.003757
# Validation Loss: 597.6343
# Epoch [59/100], Training Loss: 1209.2504, LR: 0.003605
# Validation Loss: 597.6681
# Epoch [60/100], Training Loss: 1182.3661, LR: 0.003455
# Validation Loss: 597.6714
# Epoch [61/100], Training Loss: 1177.1216, LR: 0.003306
# Validation Loss: 597.7522
# Epoch [62/100], Training Loss: 1175.2484, LR: 0.003159
# Validation Loss: 597.8886
# Epoch [63/100], Training Loss: 1185.1537, LR: 0.003014
# Validation Loss: 597.9080
# Epoch [64/100], Training Loss: 1177.2124, LR: 0.002871
# Validation Loss: 597.8570
# Epoch [65/100], Training Loss: 1184.6965, LR: 0.002730
# Validation Loss: 597.9025
# Epoch [66/100], Training Loss: 1179.0881, LR: 0.002591
# Validation Loss: 597.9425
# Epoch [67/100], Training Loss: 1186.3572, LR: 0.002455
# Validation Loss: 598.0709
# Epoch [68/100], Training Loss: 1182.5179, LR: 0.002321
# Validation Loss: 598.1216
# Epoch [69/100], Training Loss: 1181.0255, LR: 0.002190
# Validation Loss: 598.0993
# Epoch [70/100], Training Loss: 1179.8711, LR: 0.002061
# Validation Loss: 597.8764
# Epoch [71/100], Training Loss: 1177.4427, LR: 0.001935
# Validation Loss: 597.8989
# Epoch [72/100], Training Loss: 1182.6229, LR: 0.001813
# Validation Loss: 597.9403
# Epoch [73/100], Training Loss: 1179.3802, LR: 0.001693
# Validation Loss: 597.9279
# Epoch [74/100], Training Loss: 1192.6768, LR: 0.001577
# Validation Loss: 597.8606
# Epoch [75/100], Training Loss: 1176.9962, LR: 0.001464
# Validation Loss: 597.8078
# Epoch [76/100], Training Loss: 1182.3952, LR: 0.001355
# Validation Loss: 597.8186
# Epoch [77/100], Training Loss: 1180.1402, LR: 0.001249
# Validation Loss: 597.8342
# Epoch [78/100], Training Loss: 1181.4214, LR: 0.001147
# Validation Loss: 597.8717
# Epoch [79/100], Training Loss: 1188.1759, LR: 0.001049
# Validation Loss: 597.8686
# Epoch [80/100], Training Loss: 1177.3164, LR: 0.000955
# Validation Loss: 597.9058
# Epoch [81/100], Training Loss: 1178.4125, LR: 0.000865
# Validation Loss: 597.9178
# Epoch [82/100], Training Loss: 1191.6471, LR: 0.000778
# Validation Loss: 597.9142
# Epoch [83/100], Training Loss: 1182.1117, LR: 0.000696
# Validation Loss: 597.9200
# Epoch [84/100], Training Loss: 1192.2711, LR: 0.000618
# Validation Loss: 597.9001
# Epoch [85/100], Training Loss: 1178.7440, LR: 0.000545
# Validation Loss: 597.9279
# Epoch [86/100], Training Loss: 1173.3420, LR: 0.000476
# Validation Loss: 597.9032
# Epoch [87/100], Training Loss: 1178.7419, LR: 0.000411
# Validation Loss: 597.9177
# Epoch [88/100], Training Loss: 1181.7850, LR: 0.000351
# Validation Loss: 597.9278
# Epoch [89/100], Training Loss: 1178.9664, LR: 0.000296
# Validation Loss: 597.9131
# Epoch [90/100], Training Loss: 1177.5981, LR: 0.000245
# Validation Loss: 597.9130
# Epoch [91/100], Training Loss: 1176.8940, LR: 0.000199
# Validation Loss: 597.9164
# Epoch [92/100], Training Loss: 1182.7638, LR: 0.000157
# Validation Loss: 597.9092
# Epoch [93/100], Training Loss: 1175.2087, LR: 0.000120
# Validation Loss: 597.9109
# Epoch [94/100], Training Loss: 1183.5186, LR: 0.000089
# Validation Loss: 597.9119
# Epoch [95/100], Training Loss: 1175.5014, LR: 0.000062
# Validation Loss: 597.9132
# Epoch [96/100], Training Loss: 1182.9456, LR: 0.000039
# Validation Loss: 597.9126
# Epoch [97/100], Training Loss: 1183.8915, LR: 0.000022
# Validation Loss: 597.9119
# Epoch [98/100], Training Loss: 1184.8079, LR: 0.000010
# Validation Loss: 597.9116
# Epoch [99/100], Training Loss: 1178.3922, LR: 0.000002
# Validation Loss: 597.9118
# Epoch [100/100], Training Loss: 1179.6155, LR: 0.000000
# Validation Loss: 597.9117
# Training complete. Best validation loss: 596.0918. Model saved to transformer_external_model.pth.

# %%
def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss_curves(train_losses, val_losses)

# %%
from lib.metrics import (
    compute_predicted_positions,
    compute_mean_ade,
    compute_fde,
    compute_directional_accuracy,
    compute_linear_wade,
    compute_exponential_wade
) # add new imports here as new metrics created

x = torch.tensor(X_val, dtype=torch.float32).to("cuda")
y = torch.tensor(y_val, dtype=torch.float32).to("cuda")
# Compute metrics
with torch.no_grad():
    pred_position = compute_predicted_positions(model, x, y)
    mean_ade = compute_mean_ade(pred_position, y)
    fde = compute_fde(pred_position, y)
    directional_accuracy = compute_directional_accuracy(pred_position, y)
    l_wade = compute_linear_wade(pred_position, y)
    
    alpha = 0.5 #Smaller alpha -> more uniform weights, larger alpha -> more emphasis on earlier timesteps (defaults to 0.1)
    e_wade = compute_exponential_wade(pred_position, y, alpha=alpha) 

print(f"Mean Average Displacement Error (MADE): {mean_ade:.4f}")
print(f"Final Displacement Error (FDE): {fde:.4f}")
print(f"Directional Accuracy (DA): {directional_accuracy:.4f}")
print(f"Linear Weighted Average Displacement Error (LWADE): {l_wade:.4f}")
print(f"Exponential Weighted Average Displacement Error (EWADE) with alpha={alpha}: {e_wade:.4f}")
print(f"Overall Score (Lower is better) = {e_wade + 0.5 * fde - 0.5 * directional_accuracy}")
# Out:
# Mean Average Displacement Error (MADE): 1.1716
# Final Displacement Error (FDE): 2.3318
# Directional Accuracy (DA): -0.1314
# Linear Weighted Average Displacement Error (LWADE): 0.0787
# Exponential Weighted Average Displacement Error (EWADE) with alpha=0.5: 0.0397
# Overall Score (Lower is better) = 1.2713210880756378

# %%
# Example 400 - straight path towards top right
example_index = 400
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 369 - very slight curve
example_index = 369
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 411 - straight path towards bottom left
example_index = 411
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 31 - No movement
example_index = 31
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 291 - Sharp turn
example_index = 291
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 370 - Smooth slight turn
example_index = 370
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 77 - smooth 90 degree turn
example_index = 77
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()
