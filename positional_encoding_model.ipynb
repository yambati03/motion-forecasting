# %% [markdown]
# ## Positional Encoding Model

# %%
import numpy as np
import pickle

import torch
from torch import nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
run_local = True # change to False if using google drive

if run_local: # place pickle file in same directory as this ipynb
    data_path = 'parsed_data_no_timestamps.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)
else:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/MyDrive/CS7643Group/Dataset/parsed_data_no_timestamps.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)

print(f"Shape of full dataset: {data.shape}")

X_train = data[:int(0.8*len(data)), :80, :]
X_val = data[int(0.8*len(data)): , :80, :]

y_train = data[:int(0.8*len(data)), 80:, :]
y_val = data[int(0.8*len(data)): , 80:, :]

print("For each input state: X position, Y position, X velocity, Y velocity, Heading")
print("For each output state: X velocity, Y velocity")

print("\nTraining Data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")

print("\nValidation Data:") 
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Shape of full dataset: (2933, 90, 5)
# For each input state: X position, Y position, X velocity, Y velocity, Heading
# For each output state: X velocity, Y velocity
#
# Training Data:
# X_train shape: (2346, 80, 5)
# y_train shape: (2346, 10, 5)
#
# Validation Data:
# X_val shape: (587, 80, 5)
# y_val shape: (587, 10, 5)

# %%
import math
import torch
import torch.nn as nn

class TrajectoryLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_features=2, output_timesteps=10, num_layers=1, dropout=0.5):
        super(TrajectoryLSTM, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_features = output_features
        self.output_timesteps = output_timesteps
        self.num_layers = num_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout)  # Dropout layer

        # Attention mechanism
        self.attention = nn.Linear(hidden_size, 1)  # To compute attention scores
        self.softmax = nn.Softmax(dim=1)  # For normalizing attention scores

        # Fully connected layers
        self.fc = nn.Sequential(
            nn.Linear(hidden_size, 64),
            nn.BatchNorm1d(64),
            nn.Dropout(0.3),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.BatchNorm1d(32),
            nn.Dropout(0.3),
            nn.ReLU(),
            nn.Linear(32, output_features * output_timesteps)
        )

    def positional_encoding(self, seq_length, dim):
        # Create the positional encoding matrix
        pos = torch.arange(seq_length, dtype=torch.float32).unsqueeze(1)
        i = torch.arange(dim, dtype=torch.float32).unsqueeze(0)

        # Compute sinusoidal functions
        angle_rates = 1 / (10000 ** (2 * (i // 2) / dim))
        angle_rads = pos * angle_rates

        # Apply sin to even indices and cos to odd indices
        pos_enc = torch.zeros((seq_length, dim))
        pos_enc[:, 0::2] = torch.sin(angle_rads[:, 0::2])  # sin for even indices
        pos_enc[:, 1::2] = torch.cos(angle_rads[:, 1::2])  # cos for odd indices

        return pos_enc

    def forward(self, x):
        batch_size, seq_length, _ = x.size()

        # Add positional encoding
        pos_enc = self.positional_encoding(seq_length, self.input_size).to(x.device)
        x = x + pos_enc.unsqueeze(0)  # Broadcast to batch size

        # LSTM forward pass
        lstm_out, (hn, _) = self.lstm(x)

        # Compute attention scores
        attn_scores = self.attention(lstm_out)  # (batch_size, seq_length, 1)
        attn_weights = self.softmax(attn_scores)  # Normalize to get weights

        # Apply attention weights to LSTM outputs
        weighted_output = lstm_out * attn_weights  # (batch_size, seq_length, hidden_size)
        context_vector = torch.sum(weighted_output, dim=1)  # Sum across seq_length

        # Apply dropout and fully connected layers
        context_vector = self.dropout(context_vector)
        out = self.fc(context_vector)  # (batch_size, output_timesteps * output_features)
        return out.view(-1, self.output_timesteps, self.output_features)  # Reshape to (batch_size, output_timesteps, output_features)

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from loss_functions import get_loss_function

# Initialize lists to store loss history
train_losses = []
val_losses = []

def train_model(model, train_loader, val_loader, num_epochs=10, initial_lr=0.001, T_max=10, loss_fn=nn.MSELoss()):
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

    best_val_loss = float('inf')
    model_save_path = "best_positional_encoding_model.pth"  # Save path for the best model

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        epoch_train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")

            optimizer.zero_grad()
            predictions = model(batch_x)
            loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_train_loss += loss.item()

        scheduler.step()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}')

        # Validation loop
        model.eval()
        epoch_val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
                predictions = model(batch_x)
                loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
                epoch_val_loss += loss.item()

            avg_val_loss = epoch_val_loss / len(val_loader)
            val_losses.append(avg_val_loss)
            print(f'Validation Loss: {avg_val_loss:.4f}')

            # Save the model if it has the best validation loss (Comment out if you don't want to save)
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(model.state_dict(), model_save_path)
                print(f"Saved best model with validation loss: {best_val_loss:.4f}")

    print(f"Training complete. Best validation loss: {best_val_loss:.4f}. Model saved to {model_save_path}.")


train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
# Mess with batch size here
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


input_size = X_train.shape[2]
hidden_size = 64 # changeable
model = TrajectoryLSTM(input_size, hidden_size, output_features=2, output_timesteps=10, num_layers=4).to("cuda")

loss_weights = { # Update weights of different loss terms 
    "position_loss": 1.0,
    "velocity_loss": 0.5,
    "smoothness_loss": 0.25,
    "terminal_loss": 2.0,
    "delta_loss": 0.5
}
# Customize loss function here (Everything is True/False except time_weighting_scheme)
loss_fn = get_loss_function(
    "trajectory_loss", # trajectory_loss is just position loss if everything else is False
    use_velocity_loss=True,
    use_smoothness_loss=True,
    use_terminal_loss=True,
    time_weighting_scheme='Exponential',  #None, Linear, Exponential
    use_delta_loss=True,
    prediction_horizon=10, # change to match predicted timesteps (used for time)
    loss_weights=loss_weights # defaults to ALL = 1.0 if not included
) # Add more lines as new loss functions are added

# mess with epochs, initial_lr and T_max here
train_model(model, train_loader, val_loader, num_epochs=100, initial_lr=1e-2, T_max=100, loss_fn=loss_fn)
# Out:
# Epoch [1/100], Training Loss: 25964.1947, LR: 0.009998
# Validation Loss: 12610.3727
# Saved best model with validation loss: 12610.3727
# Epoch [2/100], Training Loss: 24204.1981, LR: 0.009990
# Validation Loss: 11443.3497
# Saved best model with validation loss: 11443.3497
# Epoch [3/100], Training Loss: 24326.9492, LR: 0.009978
# Validation Loss: 11595.2328
# Epoch [4/100], Training Loss: 23634.9049, LR: 0.009961
# Validation Loss: 11452.2838
# Epoch [5/100], Training Loss: 23354.2143, LR: 0.009938
# Validation Loss: 11302.2222
# Saved best model with validation loss: 11302.2222
# Epoch [6/100], Training Loss: 23432.9143, LR: 0.009911
# Validation Loss: 11253.2878
# Saved best model with validation loss: 11253.2878
# Epoch [7/100], Training Loss: 23241.5259, LR: 0.009880
# Validation Loss: 11480.3227
# Epoch [8/100], Training Loss: 23101.8128, LR: 0.009843
# Validation Loss: 11552.3162
# Epoch [9/100], Training Loss: 23247.2381, LR: 0.009801
# Validation Loss: 11433.0971
# Epoch [10/100], Training Loss: 23237.2646, LR: 0.009755
# Validation Loss: 11331.7974
# Epoch [11/100], Training Loss: 22719.0882, LR: 0.009704
# Validation Loss: 11049.1481
# Saved best model with validation loss: 11049.1481
# Epoch [12/100], Training Loss: 23068.0139, LR: 0.009649
# Validation Loss: 11076.2118
# Epoch [13/100], Training Loss: 23150.8018, LR: 0.009589
# Validation Loss: 11020.8421
# Saved best model with validation loss: 11020.8421
# Epoch [14/100], Training Loss: 22993.4586, LR: 0.009524
# Validation Loss: 11059.7848
# Epoch [15/100], Training Loss: 22972.2528, LR: 0.009455
# Validation Loss: 11093.6547
# Epoch [16/100], Training Loss: 22630.6940, LR: 0.009382
# Validation Loss: 10955.2708
# Saved best model with validation loss: 10955.2708
# Epoch [17/100], Training Loss: 22516.4514, LR: 0.009304
# Validation Loss: 10842.1966
# Saved best model with validation loss: 10842.1966
# Epoch [18/100], Training Loss: 23227.8196, LR: 0.009222
# Validation Loss: 11105.2953
# Epoch [19/100], Training Loss: 22973.2987, LR: 0.009135
# Validation Loss: 11036.9802
# Epoch [20/100], Training Loss: 22737.1774, LR: 0.009045
# Validation Loss: 11071.3184
# Epoch [21/100], Training Loss: 22596.3345, LR: 0.008951
# Validation Loss: 10875.2735
# Epoch [22/100], Training Loss: 22759.4772, LR: 0.008853
# Validation Loss: 10901.5452
# Epoch [23/100], Training Loss: 22573.3001, LR: 0.008751
# Validation Loss: 10885.1876
# Epoch [24/100], Training Loss: 22538.5881, LR: 0.008645
# Validation Loss: 10997.4905
# Epoch [25/100], Training Loss: 22503.0408, LR: 0.008536
# Validation Loss: 10878.6506
# Epoch [26/100], Training Loss: 22805.4399, LR: 0.008423
# Validation Loss: 10956.3245
# Epoch [27/100], Training Loss: 22631.1113, LR: 0.008307
# Validation Loss: 10898.8462
# Epoch [28/100], Training Loss: 22388.1814, LR: 0.008187
# Validation Loss: 10851.2358
# Epoch [29/100], Training Loss: 22648.5151, LR: 0.008065
# Validation Loss: 11051.2546
# Epoch [30/100], Training Loss: 22303.8297, LR: 0.007939
# Validation Loss: 11084.3943
# Epoch [31/100], Training Loss: 22290.2492, LR: 0.007810
# Validation Loss: 10845.7242
# Epoch [32/100], Training Loss: 22366.0256, LR: 0.007679
# Validation Loss: 10783.6817
# Saved best model with validation loss: 10783.6817
# Epoch [33/100], Training Loss: 22277.6489, LR: 0.007545
# Validation Loss: 10970.7889
# Epoch [34/100], Training Loss: 22263.0610, LR: 0.007409
# Validation Loss: 10746.4169
# Saved best model with validation loss: 10746.4169
# Epoch [35/100], Training Loss: 23177.5179, LR: 0.007270
# Validation Loss: 11035.3656
# Epoch [36/100], Training Loss: 22186.0126, LR: 0.007129
# Validation Loss: 10951.1163
# Epoch [37/100], Training Loss: 22905.5510, LR: 0.006986
# Validation Loss: 11071.3901
# Epoch [38/100], Training Loss: 22200.9148, LR: 0.006841
# Validation Loss: 10784.8001
# Epoch [39/100], Training Loss: 22339.8718, LR: 0.006694
# Validation Loss: 10954.3676
# Epoch [40/100], Training Loss: 22209.2687, LR: 0.006545
# Validation Loss: 10888.6485
# Epoch [41/100], Training Loss: 22185.6512, LR: 0.006395
# Validation Loss: 10938.4986
# Epoch [42/100], Training Loss: 22182.7625, LR: 0.006243
# Validation Loss: 10910.5353
# Epoch [43/100], Training Loss: 22384.7669, LR: 0.006091
# Validation Loss: 10877.3377
# Epoch [44/100], Training Loss: 22186.2914, LR: 0.005937
# Validation Loss: 10912.6552
# Epoch [45/100], Training Loss: 22179.8411, LR: 0.005782
# Validation Loss: 10934.3378
# Epoch [46/100], Training Loss: 22592.9546, LR: 0.005627
# Validation Loss: 11014.0789
# Epoch [47/100], Training Loss: 22108.8142, LR: 0.005471
# Validation Loss: 10932.9429
# Epoch [48/100], Training Loss: 22196.8864, LR: 0.005314
# Validation Loss: 10863.0978
# Epoch [49/100], Training Loss: 22272.8457, LR: 0.005157
# Validation Loss: 10805.1219
# Epoch [50/100], Training Loss: 22121.8256, LR: 0.005000
# Validation Loss: 10911.7540
# Epoch [51/100], Training Loss: 22056.8825, LR: 0.004843
# Validation Loss: 10962.0586
# Epoch [52/100], Training Loss: 22061.7347, LR: 0.004686
# Validation Loss: 10966.3865
# Epoch [53/100], Training Loss: 21992.3649, LR: 0.004529
# Validation Loss: 11028.4515
# Epoch [54/100], Training Loss: 22018.5088, LR: 0.004373
# Validation Loss: 10806.8967
# Epoch [55/100], Training Loss: 22106.3195, LR: 0.004218
# Validation Loss: 10817.2057
# Epoch [56/100], Training Loss: 22612.6285, LR: 0.004063
# Validation Loss: 11008.0012
# Epoch [57/100], Training Loss: 21969.9722, LR: 0.003909
# Validation Loss: 10751.4472
# Epoch [58/100], Training Loss: 22589.6188, LR: 0.003757
# Validation Loss: 10922.8150
# Epoch [59/100], Training Loss: 21885.4769, LR: 0.003605
# Validation Loss: 10977.9820
# Epoch [60/100], Training Loss: 22340.0644, LR: 0.003455
# Validation Loss: 10997.8874
# Epoch [61/100], Training Loss: 22237.1289, LR: 0.003306
# Validation Loss: 10957.4476
# Epoch [62/100], Training Loss: 21923.6746, LR: 0.003159
# Validation Loss: 10933.0339
# Epoch [63/100], Training Loss: 22078.3635, LR: 0.003014
# Validation Loss: 10789.3612
# Epoch [64/100], Training Loss: 21896.7803, LR: 0.002871
# Validation Loss: 10863.8077
# Epoch [65/100], Training Loss: 21931.2729, LR: 0.002730
# Validation Loss: 10833.7351
# Epoch [66/100], Training Loss: 22171.3169, LR: 0.002591
# Validation Loss: 10831.6495
# Epoch [67/100], Training Loss: 22753.0117, LR: 0.002455
# Validation Loss: 10867.7806
# Epoch [68/100], Training Loss: 21884.1046, LR: 0.002321
# Validation Loss: 10838.5017
# Epoch [69/100], Training Loss: 22072.7007, LR: 0.002190
# Validation Loss: 10797.7158
# Epoch [70/100], Training Loss: 21790.3617, LR: 0.002061
# Validation Loss: 10824.4381
# Epoch [71/100], Training Loss: 21983.6592, LR: 0.001935
# Validation Loss: 10800.4761
# Epoch [72/100], Training Loss: 21929.1100, LR: 0.001813
# Validation Loss: 10793.4981
# Epoch [73/100], Training Loss: 22517.7284, LR: 0.001693
# Validation Loss: 10879.0322
# Epoch [74/100], Training Loss: 21901.8898, LR: 0.001577
# Validation Loss: 10893.0886
# Epoch [75/100], Training Loss: 21941.8945, LR: 0.001464
# Validation Loss: 10936.1802
# Epoch [76/100], Training Loss: 21906.2185, LR: 0.001355
# Validation Loss: 10878.2382
# Epoch [77/100], Training Loss: 21947.0018, LR: 0.001249
# Validation Loss: 10914.8054
# Epoch [78/100], Training Loss: 21921.2291, LR: 0.001147
# Validation Loss: 10992.3785
# Epoch [79/100], Training Loss: 21826.3752, LR: 0.001049
# Validation Loss: 10862.1574
# Epoch [80/100], Training Loss: 21791.8369, LR: 0.000955
# Validation Loss: 10960.0017
# Epoch [81/100], Training Loss: 22501.0610, LR: 0.000865
# Validation Loss: 11063.0517
# Epoch [82/100], Training Loss: 22067.8133, LR: 0.000778
# Validation Loss: 10784.5380
# Epoch [83/100], Training Loss: 21826.2393, LR: 0.000696
# Validation Loss: 10894.3888
# Epoch [84/100], Training Loss: 21836.1608, LR: 0.000618
# Validation Loss: 10872.3005
# Epoch [85/100], Training Loss: 22133.9224, LR: 0.000545
# Validation Loss: 11116.3434
# Epoch [86/100], Training Loss: 23029.8215, LR: 0.000476
# Validation Loss: 11118.0852
# Epoch [87/100], Training Loss: 21891.1105, LR: 0.000411
# Validation Loss: 10865.0025
# Epoch [88/100], Training Loss: 22051.0980, LR: 0.000351
# Validation Loss: 10903.7176
# Epoch [89/100], Training Loss: 22194.7538, LR: 0.000296
# Validation Loss: 10953.7866
# Epoch [90/100], Training Loss: 21857.3145, LR: 0.000245
# Validation Loss: 10921.9599
# Epoch [91/100], Training Loss: 21969.3539, LR: 0.000199
# Validation Loss: 10854.4053
# Epoch [92/100], Training Loss: 21905.0437, LR: 0.000157
# Validation Loss: 10832.2268
# Epoch [93/100], Training Loss: 22322.4457, LR: 0.000120
# Validation Loss: 10921.7429
# Epoch [94/100], Training Loss: 22293.8024, LR: 0.000089
# Validation Loss: 10863.6710
# Epoch [95/100], Training Loss: 21907.4176, LR: 0.000062
# Validation Loss: 10972.9997
# Epoch [96/100], Training Loss: 21803.3636, LR: 0.000039
# Validation Loss: 10788.0482
# Epoch [97/100], Training Loss: 22061.4691, LR: 0.000022
# Validation Loss: 10824.0997
# Epoch [98/100], Training Loss: 22065.4472, LR: 0.000010
# Validation Loss: 10860.0711
# Epoch [99/100], Training Loss: 21949.4388, LR: 0.000002
# Validation Loss: 11069.1049
# Epoch [100/100], Training Loss: 22131.8222, LR: 0.000000
# Validation Loss: 10877.6027
# Training complete. Best validation loss: 10746.4169. Model saved to best_positional_encoding_model.pth.

# %%
def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss_curves(train_losses, val_losses)

# %%
from metrics import (
    compute_predicted_positions,
    compute_mean_ade,
    compute_fde,
    compute_directional_accuracy,
    compute_linear_wade,
    compute_exponential_wade
) # add new imports here as new metrics created

x = torch.tensor(X_val, dtype=torch.float32).to("cuda")
y = torch.tensor(y_val, dtype=torch.float32).to("cuda")
# Compute metrics
with torch.no_grad():
    pred_position = compute_predicted_positions(model, x, y)
    mean_ade = compute_mean_ade(pred_position, y)
    fde = compute_fde(pred_position, y)
    directional_accuracy = compute_directional_accuracy(pred_position, y)
    l_wade = compute_linear_wade(pred_position, y)
    
    alpha = 0.5 #Smaller alpha -> more uniform weights, larger alpha -> more emphasis on earlier timesteps (defaults to 0.1)
    e_wade = compute_exponential_wade(pred_position, y, alpha=alpha) 

print(f"Mean Average Displacement Error (MADE): {mean_ade:.4f}")
print(f"Final Displacement Error (FDE): {fde:.4f}")
print(f"Directional Accuracy (DA): {directional_accuracy:.4f}")
print(f"Linear Weighted Average Displacement Error (LWADE): {l_wade:.4f}")
print(f"Exponential Weighted Average Displacement Error (EWADE) with alpha={alpha}: {e_wade:.4f}")
print(f"Overall Score (Lower is better) = {e_wade + 0.5 * fde - 0.5 * directional_accuracy}")
# Out:
# Mean Average Displacement Error (MADE): 2.9386
# Final Displacement Error (FDE): 6.5523
# Directional Accuracy (DA): 0.3185
# Linear Weighted Average Displacement Error (LWADE): 0.2030
# Exponential Weighted Average Displacement Error (EWADE) with alpha=0.5: 0.1280
# Overall Score (Lower is better) = 3.2448771446943283

# %%
# Example 400 - straight path towards top right
example_index = 400
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 369 - very slight curve
example_index = 369
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 411 - straight path towards bottom left
example_index = 411
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 31 - No movement
example_index = 31
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 291 - Sharp turn
example_index = 291
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 370 - Smooth slight turn
example_index = 370
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 77 - smooth 90 degree turn
example_index = 77
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()
