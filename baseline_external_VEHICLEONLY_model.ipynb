# %% [markdown]
# ## Baseline Model WITH EXTERNAL FEATURES

# %%
import numpy as np
import pickle

import torch
from torch import nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
run_local = True # change to False if using google drive
from enum import Enum

if run_local: # place pickle file in same directory as this ipynb
    data_path = 'parsed_data_final_srishti.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)
else:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/MyDrive/CS7643Group/Dataset/parsed_data_final_srishti.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)

print(f"Shape of full dataset: {data.shape}")
data = data[:, :-1, :]


class FeatureOption(Enum):
    VEHICLE_ONLY = 1 # Vehicle features only
    VEHICLE_AND_PEDESTRIAN = 2 # Vehicle and Pedestrian features:
    VEHICLE_PEDESTRIAN_ROADGRAPH = 3 # Vehicle and Pedestrian and Roadgraph features:
    VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE = 4 # Vehicle and Pedestrian and Roadgraph and Bicycle features

feature_option = FeatureOption.VEHICLE_ONLY # choose from: VEHICLE_ONLY, VEHICLE_AND_PEDESTRIAN, VEHICLE_PEDESTRIAN_ROADGRAPH, VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE

if feature_option == FeatureOption.VEHICLE_ONLY: # Vehicle Only
    data = data[:, :, 1:6]
elif feature_option == FeatureOption.VEHICLE_AND_PEDESTRIAN: # Vehicle and pedestrian
    data = data[:, :, 1:8]
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH: # Vehicle, pedestrian, and roadgraph 
    vehicle_pedestrian = data[:, :, 1:8]
    roadgraph = data[:, :, 10:]
    data = np.concatenate((vehicle_pedestrian, roadgraph), axis = 2)
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE: # vehicle, pedestrian, roadgraph and bicycle
    data = data[:, :, 1:]
else:
    raise Exception("Invalid Choice")

X_train = data[:int(0.8*len(data)), :80, :]
X_val = data[int(0.8*len(data)): , :80, :]

y_train = data[:int(0.8*len(data)), 80:, :]
y_val = data[int(0.8*len(data)): , 80:, :]

print("For each input state: X position, Y position, X velocity, Y velocity, Heading")
print("For each output state: X velocity, Y velocity")
print("Feature Type: ", feature_option)
print("\nTraining Data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")

print("\nValidation Data:") 
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Shape of full dataset: (2933, 91, 14)
# For each input state: X position, Y position, X velocity, Y velocity, Heading
# For each output state: X velocity, Y velocity
# Feature Type:  FeatureOption.VEHICLE_ONLY
#
# Training Data:
# X_train shape: (2346, 80, 5)
# y_train shape: (2346, 10, 5)
#
# Validation Data:
# X_val shape: (587, 80, 5)
# y_val shape: (587, 10, 5)

# %%
import torch
import torch.nn as nn

class TrajectoryLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_features=2, output_timesteps=10, num_layers=1):  # Set default n to 10
        super(TrajectoryLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_features * output_timesteps)
        self.output_features = output_features
        self.output_timesteps = output_timesteps

    def forward(self, x):
        # x: (batch_size, seq_length, input_size)
        _, (hn, _) = self.lstm(x)
        # hn: (num_layers, batch_size, hidden_size)
        # want to take the last layer so that you are left with (batch_size, hidden_size)
        out = self.fc(hn[-1])
        return out.view(-1, self.output_timesteps, self.output_features)  # Reshape to (batch_size, 10, input_size)

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from loss_functions import get_loss_function

# Initialize lists to store loss history
train_losses = []
val_losses = []

def train_model(model, train_loader, val_loader, num_epochs=10, initial_lr=0.001, T_max=10, loss_fn=nn.MSELoss()):
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

    best_val_loss = float('inf')
    model_save_path = "baseline_external_model.pth"  # Save path for the best model

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        epoch_train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")

            optimizer.zero_grad()
            predictions = model(batch_x)
            # print(predictions.shape)
            loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_train_loss += loss.item()

        scheduler.step()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}')

        # Validation loop
        model.eval()
        epoch_val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
                predictions = model(batch_x)
                loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
                epoch_val_loss += loss.item()

            avg_val_loss = epoch_val_loss / len(val_loader)
            val_losses.append(avg_val_loss)
            print(f'Validation Loss: {avg_val_loss:.4f}')

            # Save the model if it has the best validation loss (Comment out if you don't want to save)
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(model.state_dict(), model_save_path)
                print(f"Saved best model with validation loss: {best_val_loss:.4f}")

    print(f"Training complete. Best validation loss: {best_val_loss:.4f}. Model saved to {model_save_path}.")


train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
# Mess with batch size here
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


input_size = X_train.shape[2]
# print(input_size)
hidden_size = 64 # changeable
model = TrajectoryLSTM(input_size, hidden_size, output_features=2, output_timesteps=10, num_layers=1).to("cuda")

loss_weights = { # Update weights of different loss terms 
    "position_loss": 1.0,
    "velocity_loss": 0.5,
    "smoothness_loss": 0.25,
    "terminal_loss": 2.0,
    "delta_loss": 0.5
}
# Customize loss function here (Everything is True/False except time_weighting_scheme)
loss_fn = get_loss_function(
    "trajectory_loss", # trajectory_loss is just position loss if everything else is False
    use_velocity_loss=True,
    use_smoothness_loss=True,
    use_terminal_loss=True,
    time_weighting_scheme='Exponential',  #None, Linear, Exponential
    use_delta_loss=True,
    prediction_horizon=10, # change to match predicted timesteps (used for time)
    loss_weights=loss_weights # defaults to ALL = 1.0 if not included
) # Add more lines as new loss functions are added

# mess with epochs, initial_lr and T_max here
train_model(model, train_loader, val_loader, num_epochs=100, initial_lr=1e-2, T_max=100, loss_fn=loss_fn)
# Out:
# Epoch [1/100], Training Loss: 25848.9708, LR: 0.009998
# Validation Loss: 11684.3918
# Saved best model with validation loss: 11684.3918
# Epoch [2/100], Training Loss: 23508.1100, LR: 0.009990
# Validation Loss: 11166.7616
# Saved best model with validation loss: 11166.7616
# Epoch [3/100], Training Loss: 22824.6156, LR: 0.009978
# Validation Loss: 10982.0066
# Saved best model with validation loss: 10982.0066
# Epoch [4/100], Training Loss: 22586.1059, LR: 0.009961
# Validation Loss: 10871.2966
# Saved best model with validation loss: 10871.2966
# Epoch [5/100], Training Loss: 22143.5627, LR: 0.009938
# Validation Loss: 10805.9494
# Saved best model with validation loss: 10805.9494
# Epoch [6/100], Training Loss: 22042.0874, LR: 0.009911
# Validation Loss: 10762.8634
# Saved best model with validation loss: 10762.8634
# Epoch [7/100], Training Loss: 21856.8898, LR: 0.009880
# Validation Loss: 10730.5515
# Saved best model with validation loss: 10730.5515
# Epoch [8/100], Training Loss: 22220.4355, LR: 0.009843
# Validation Loss: 10738.3182
# Epoch [9/100], Training Loss: 22421.1536, LR: 0.009801
# Validation Loss: 10765.5916
# Epoch [10/100], Training Loss: 21838.9041, LR: 0.009755
# Validation Loss: 10703.2206
# Saved best model with validation loss: 10703.2206
# Epoch [11/100], Training Loss: 21752.8173, LR: 0.009704
# Validation Loss: 10705.9124
# Epoch [12/100], Training Loss: 21835.9018, LR: 0.009649
# Validation Loss: 10676.6525
# Saved best model with validation loss: 10676.6525
# Epoch [13/100], Training Loss: 21660.3929, LR: 0.009589
# Validation Loss: 10668.0345
# Saved best model with validation loss: 10668.0345
# Epoch [14/100], Training Loss: 21633.8426, LR: 0.009524
# Validation Loss: 10678.6997
# Epoch [15/100], Training Loss: 22190.7809, LR: 0.009455
# Validation Loss: 10686.6535
# Epoch [16/100], Training Loss: 21922.2446, LR: 0.009382
# Validation Loss: 10657.8509
# Saved best model with validation loss: 10657.8509
# Epoch [17/100], Training Loss: 21835.0045, LR: 0.009304
# Validation Loss: 10694.2482
# Epoch [18/100], Training Loss: 21495.7100, LR: 0.009222
# Validation Loss: 10674.4702
# Epoch [19/100], Training Loss: 21825.9159, LR: 0.009135
# Validation Loss: 10676.0366
# Epoch [20/100], Training Loss: 21550.0528, LR: 0.009045
# Validation Loss: 10696.5191
# Epoch [21/100], Training Loss: 21601.5297, LR: 0.008951
# Validation Loss: 10682.5396
# Epoch [22/100], Training Loss: 21481.1057, LR: 0.008853
# Validation Loss: 10667.5337
# Epoch [23/100], Training Loss: 21534.2085, LR: 0.008751
# Validation Loss: 10651.0951
# Saved best model with validation loss: 10651.0951
# Epoch [24/100], Training Loss: 21545.0793, LR: 0.008645
# Validation Loss: 10645.6803
# Saved best model with validation loss: 10645.6803
# Epoch [25/100], Training Loss: 21550.4585, LR: 0.008536
# Validation Loss: 10629.6896
# Saved best model with validation loss: 10629.6896
# Epoch [26/100], Training Loss: 21471.5480, LR: 0.008423
# Validation Loss: 10645.7846
# Epoch [27/100], Training Loss: 21685.3841, LR: 0.008307
# Validation Loss: 10698.3539
# Epoch [28/100], Training Loss: 21490.7541, LR: 0.008187
# Validation Loss: 10660.8709
# Epoch [29/100], Training Loss: 21369.5220, LR: 0.008065
# Validation Loss: 10691.2465
# Epoch [30/100], Training Loss: 21553.7065, LR: 0.007939
# Validation Loss: 10686.5204
# Epoch [31/100], Training Loss: 21649.8438, LR: 0.007810
# Validation Loss: 10658.6353
# Epoch [32/100], Training Loss: 22270.3278, LR: 0.007679
# Validation Loss: 10679.0495
# Epoch [33/100], Training Loss: 21315.1225, LR: 0.007545
# Validation Loss: 10667.7325
# Epoch [34/100], Training Loss: 21359.7963, LR: 0.007409
# Validation Loss: 10703.4423
# Epoch [35/100], Training Loss: 21387.4965, LR: 0.007270
# Validation Loss: 10693.6840
# Epoch [36/100], Training Loss: 21341.6430, LR: 0.007129
# Validation Loss: 10647.6494
# Epoch [37/100], Training Loss: 21343.6724, LR: 0.006986
# Validation Loss: 10638.0431
# Epoch [38/100], Training Loss: 21350.4904, LR: 0.006841
# Validation Loss: 10661.0413
# Epoch [39/100], Training Loss: 21540.2109, LR: 0.006694
# Validation Loss: 10662.8257
# Epoch [40/100], Training Loss: 21349.0546, LR: 0.006545
# Validation Loss: 10649.3425
# Epoch [41/100], Training Loss: 21440.1171, LR: 0.006395
# Validation Loss: 10671.7801
# Epoch [42/100], Training Loss: 21401.4141, LR: 0.006243
# Validation Loss: 10643.8313
# Epoch [43/100], Training Loss: 21273.5729, LR: 0.006091
# Validation Loss: 10658.8065
# Epoch [44/100], Training Loss: 21252.5123, LR: 0.005937
# Validation Loss: 10653.4966
# Epoch [45/100], Training Loss: 21615.8904, LR: 0.005782
# Validation Loss: 10649.6883
# Epoch [46/100], Training Loss: 21173.5532, LR: 0.005627
# Validation Loss: 10662.2494
# Epoch [47/100], Training Loss: 21274.8960, LR: 0.005471
# Validation Loss: 10643.5276
# Epoch [48/100], Training Loss: 21430.3997, LR: 0.005314
# Validation Loss: 10625.0548
# Saved best model with validation loss: 10625.0548
# Epoch [49/100], Training Loss: 21431.4385, LR: 0.005157
# Validation Loss: 10639.1660
# Epoch [50/100], Training Loss: 21350.5925, LR: 0.005000
# Validation Loss: 10639.9854
# Epoch [51/100], Training Loss: 21893.4088, LR: 0.004843
# Validation Loss: 10636.3773
# Epoch [52/100], Training Loss: 21318.1933, LR: 0.004686
# Validation Loss: 10646.4950
# Epoch [53/100], Training Loss: 21341.1662, LR: 0.004529
# Validation Loss: 10632.8302
# Epoch [54/100], Training Loss: 21264.6911, LR: 0.004373
# Validation Loss: 10659.0092
# Epoch [55/100], Training Loss: 21475.5099, LR: 0.004218
# Validation Loss: 10633.3326
# Epoch [56/100], Training Loss: 21216.7829, LR: 0.004063
# Validation Loss: 10634.3900
# Epoch [57/100], Training Loss: 21250.6902, LR: 0.003909
# Validation Loss: 10621.8755
# Saved best model with validation loss: 10621.8755
# Epoch [58/100], Training Loss: 21289.6549, LR: 0.003757
# Validation Loss: 10619.9751
# Saved best model with validation loss: 10619.9751
# Epoch [59/100], Training Loss: 21204.9010, LR: 0.003605
# Validation Loss: 10615.6722
# Saved best model with validation loss: 10615.6722
# Epoch [60/100], Training Loss: 21189.4851, LR: 0.003455
# Validation Loss: 10616.0403
# Epoch [61/100], Training Loss: 21252.4199, LR: 0.003306
# Validation Loss: 10610.6521
# Saved best model with validation loss: 10610.6521
# Epoch [62/100], Training Loss: 21338.5721, LR: 0.003159
# Validation Loss: 10603.9570
# Saved best model with validation loss: 10603.9570
# Epoch [63/100], Training Loss: 21370.3031, LR: 0.003014
# Validation Loss: 10617.4818
# Epoch [64/100], Training Loss: 21435.3858, LR: 0.002871
# Validation Loss: 10616.3477
# Epoch [65/100], Training Loss: 21191.8304, LR: 0.002730
# Validation Loss: 10617.7270
# Epoch [66/100], Training Loss: 21178.3590, LR: 0.002591
# Validation Loss: 10618.0499
# Epoch [67/100], Training Loss: 21310.3837, LR: 0.002455
# Validation Loss: 10612.6702
# Epoch [68/100], Training Loss: 21112.5512, LR: 0.002321
# Validation Loss: 10612.3740
# Epoch [69/100], Training Loss: 21917.2266, LR: 0.002190
# Validation Loss: 10610.1257
# Epoch [70/100], Training Loss: 21470.7988, LR: 0.002061
# Validation Loss: 10606.8986
# Epoch [71/100], Training Loss: 21878.5873, LR: 0.001935
# Validation Loss: 10608.4855
# Epoch [72/100], Training Loss: 21119.0784, LR: 0.001813
# Validation Loss: 10600.4635
# Saved best model with validation loss: 10600.4635
# Epoch [73/100], Training Loss: 21072.6038, LR: 0.001693
# Validation Loss: 10594.5368
# Saved best model with validation loss: 10594.5368
# Epoch [74/100], Training Loss: 21305.9732, LR: 0.001577
# Validation Loss: 10599.5446
# Epoch [75/100], Training Loss: 21127.1172, LR: 0.001464
# Validation Loss: 10599.3377
# Epoch [76/100], Training Loss: 21235.7727, LR: 0.001355
# Validation Loss: 10599.9768
# Epoch [77/100], Training Loss: 21092.3873, LR: 0.001249
# Validation Loss: 10606.1443
# Epoch [78/100], Training Loss: 21350.6142, LR: 0.001147
# Validation Loss: 10599.2779
# Epoch [79/100], Training Loss: 21042.8991, LR: 0.001049
# Validation Loss: 10599.5410
# Epoch [80/100], Training Loss: 21059.2907, LR: 0.000955
# Validation Loss: 10592.7987
# Saved best model with validation loss: 10592.7987
# Epoch [81/100], Training Loss: 21200.8776, LR: 0.000865
# Validation Loss: 10593.8854
# Epoch [82/100], Training Loss: 21136.5894, LR: 0.000778
# Validation Loss: 10593.5524
# Epoch [83/100], Training Loss: 21348.4453, LR: 0.000696
# Validation Loss: 10596.1392
# Epoch [84/100], Training Loss: 21600.0126, LR: 0.000618
# Validation Loss: 10596.6411
# Epoch [85/100], Training Loss: 21130.9103, LR: 0.000545
# Validation Loss: 10595.2171
# Epoch [86/100], Training Loss: 21024.7692, LR: 0.000476
# Validation Loss: 10596.3003
# Epoch [87/100], Training Loss: 21180.9992, LR: 0.000411
# Validation Loss: 10594.3421
# Epoch [88/100], Training Loss: 21439.6379, LR: 0.000351
# Validation Loss: 10597.5331
# Epoch [89/100], Training Loss: 21107.3740, LR: 0.000296
# Validation Loss: 10596.8095
# Epoch [90/100], Training Loss: 21033.4076, LR: 0.000245
# Validation Loss: 10594.6008
# Epoch [91/100], Training Loss: 21445.4159, LR: 0.000199
# Validation Loss: 10594.0173
# Epoch [92/100], Training Loss: 21157.1513, LR: 0.000157
# Validation Loss: 10594.4997
# Epoch [93/100], Training Loss: 21320.1064, LR: 0.000120
# Validation Loss: 10593.2677
# Epoch [94/100], Training Loss: 21275.4502, LR: 0.000089
# Validation Loss: 10593.4055
# Epoch [95/100], Training Loss: 21120.9974, LR: 0.000062
# Validation Loss: 10593.2481
# Epoch [96/100], Training Loss: 21105.3334, LR: 0.000039
# Validation Loss: 10592.8694
# Epoch [97/100], Training Loss: 21185.6118, LR: 0.000022
# Validation Loss: 10592.7689
# Saved best model with validation loss: 10592.7689
# Epoch [98/100], Training Loss: 21039.2137, LR: 0.000010
# Validation Loss: 10592.7333
# Saved best model with validation loss: 10592.7333
# Epoch [99/100], Training Loss: 21189.7675, LR: 0.000002
# Validation Loss: 10592.7845
# Epoch [100/100], Training Loss: 21073.2529, LR: 0.000000
# Validation Loss: 10592.7889
# Training complete. Best validation loss: 10592.7333. Model saved to baseline_external_model.pth.

# %%
def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss_curves(train_losses, val_losses)

# %%
from metrics import (
    compute_predicted_positions,
    compute_mean_ade,
    compute_fde,
    compute_directional_accuracy,
    compute_linear_wade,
    compute_exponential_wade
) # add new imports here as new metrics created

x = torch.tensor(X_val, dtype=torch.float32).to("cuda")
y = torch.tensor(y_val, dtype=torch.float32).to("cuda")
# Compute metrics
with torch.no_grad():
    pred_position = compute_predicted_positions(model, x, y)
    mean_ade = compute_mean_ade(pred_position, y)
    fde = compute_fde(pred_position, y)
    directional_accuracy = compute_directional_accuracy(pred_position, y)
    l_wade = compute_linear_wade(pred_position, y)
    
    alpha = 0.5 #Smaller alpha -> more uniform weights, larger alpha -> more emphasis on earlier timesteps (defaults to 0.1)
    e_wade = compute_exponential_wade(pred_position, y, alpha=alpha) 

print(f"Mean Average Displacement Error (MADE): {mean_ade:.4f}")
print(f"Final Displacement Error (FDE): {fde:.4f}")
print(f"Directional Accuracy (DA): {directional_accuracy:.4f}")
print(f"Linear Weighted Average Displacement Error (LWADE): {l_wade:.4f}")
print(f"Exponential Weighted Average Displacement Error (EWADE) with alpha={alpha}: {e_wade:.4f}")
print(f"Overall Score (Lower is better) = {e_wade + 0.5 * fde - 0.5 * directional_accuracy}")
# Out:
# Mean Average Displacement Error (MADE): 4.5236
# Final Displacement Error (FDE): 10.1040
# Directional Accuracy (DA): 0.3682
# Linear Weighted Average Displacement Error (LWADE): 0.3121
# Exponential Weighted Average Displacement Error (EWADE) with alpha=0.5: 0.1958
# Overall Score (Lower is better) = 5.063693478703499

# %%
# Example 400 - straight path towards top right
example_index = 400
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 369 - very slight curve
example_index = 369
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 411 - straight path towards bottom left
example_index = 411
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 31 - No movement
example_index = 31
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 291 - Sharp turn
example_index = 291
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 370 - Smooth slight turn
example_index = 370
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 77 - smooth 90 degree turn
example_index = 77
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()
