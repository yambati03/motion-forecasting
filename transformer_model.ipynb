# %% [markdown]
# ## Transformer Model

# %%
import numpy as np
import pickle

import torch
from torch import nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
run_local = True # change to False if using google drive

if run_local: # place pickle file in same directory as this ipynb
    data_path = 'parsed_data_no_timestamps.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)
else:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/MyDrive/CS7643Group/Dataset/parsed_data_no_timestamps.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)

print(f"Shape of full dataset: {data.shape}")

X_train = data[:int(0.8*len(data)), :80, :]
X_val = data[int(0.8*len(data)): , :80, :]

y_train = data[:int(0.8*len(data)), 80:, :]
y_val = data[int(0.8*len(data)): , 80:, :]

print("For each input state: X position, Y position, X velocity, Y velocity, Heading")
print("For each output state: X velocity, Y velocity")

print("\nTraining Data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")

print("\nValidation Data:") 
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Shape of full dataset: (2933, 90, 5)
# For each input state: X position, Y position, X velocity, Y velocity, Heading
# For each output state: X velocity, Y velocity
#
# Training Data:
# X_train shape: (2346, 80, 5)
# y_train shape: (2346, 10, 5)
#
# Validation Data:
# X_val shape: (587, 80, 5)
# y_val shape: (587, 10, 5)

# %%
import torch
import torch.nn as nn

class TrajectoryTransformer(nn.Module):
    def __init__(self, input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10, max_seq_length=100):
        super(TrajectoryTransformer, self).__init__()
        self.embedding = nn.Linear(input_size, model_dim)
        self.positional_encoding = nn.Parameter(torch.randn(max_seq_length, model_dim))
        self.transformer = nn.Transformer(
            d_model=model_dim,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            num_decoder_layers=num_layers,
            dim_feedforward=4 * model_dim,
            dropout=0.5 #dropout=0.1
        )
        self.fc = nn.Linear(model_dim, output_features * output_timesteps)
        self.output_features = output_features
        self.output_timesteps = output_timesteps

    def forward(self, x):
        # x: (batch_size, seq_length, input_size)
        batch_size, seq_length, input_size = x.size()
        src = self.embedding(x) + self.positional_encoding[:seq_length]  # Add positional encoding
        src = src.permute(1, 0, 2)  # Transformer expects (seq_len, batch_size, model_dim)

        tgt = torch.zeros_like(src)  # Dummy target (for autoregressive tasks, replace with actual decoder inputs if needed)

        # Pass through the Transformer
        output = self.transformer(src, tgt)
        output = output[-1]  # Take the last sequence position
        output = self.fc(output)
        return output.view(-1, self.output_timesteps, self.output_features)  # Reshape to (batch_size, 10, 2)

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from loss_functions import get_loss_function

# Initialize lists to store loss history
train_losses = []
val_losses = []

def train_model(model, train_loader, val_loader, num_epochs=10, initial_lr=0.001, T_max=10, loss_fn=nn.MSELoss()):
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

    best_val_loss = float('inf')
    model_save_path = "best_transformer_model.pth"  # Save path for the best model

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        epoch_train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")

            optimizer.zero_grad()
            predictions = model(batch_x)
            loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_train_loss += loss.item()

        scheduler.step()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}')

        # Validation loop
        model.eval()
        epoch_val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
                predictions = model(batch_x)
                loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
                epoch_val_loss += loss.item()

            avg_val_loss = epoch_val_loss / len(val_loader)
            val_losses.append(avg_val_loss)
            print(f'Validation Loss: {avg_val_loss:.4f}')

            # Save the model if it has the best validation loss (Comment out if you don't want to save)
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(model.state_dict(), model_save_path)
                print(f"Saved best model with validation loss: {best_val_loss:.4f}")

    print(f"Training complete. Best validation loss: {best_val_loss:.4f}. Model saved to {model_save_path}.")


train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
# Mess with batch size here
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


input_size = X_train.shape[2]
hidden_size = 64 # changeable
input_size = X_train.shape[2]

model_dim = 16  # Adjustable
num_heads = 1  # Adjustable
num_layers = 1  # Adjustable

model = TrajectoryTransformer(input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10).to("cuda")


loss_weights = { # Update weights of different loss terms 
    "position_loss": 1.0,
    "velocity_loss": 0.5,
    "smoothness_loss": 0.25,
    "terminal_loss": 2.0,
    "delta_loss": 0.5
}
# Customize loss function here (Everything is True/False except time_weighting_scheme)
loss_fn = get_loss_function(
    "trajectory_loss", # trajectory_loss is just position loss if everything else is False
    use_velocity_loss=True,
    use_smoothness_loss=True,
    use_terminal_loss=True,
    time_weighting_scheme='Exponential',  #None, Linear, Exponential
    use_delta_loss=True,
    prediction_horizon=10, # change to match predicted timesteps (used for time)
    loss_weights=loss_weights # defaults to ALL = 1.0 if not included
) # Add more lines as new loss functions are added

# mess with epochs, initial_lr and T_max here
train_model(model, train_loader, val_loader, num_epochs=100, initial_lr=1e-2, T_max=100, loss_fn=loss_fn)
# Out:
# c:\Users\rsudu\mambaforge\envs\cv_proj5\lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch [1/100], Training Loss: 26671.4413, LR: 0.009998
# Validation Loss: 12666.7290
# Saved best model with validation loss: 12666.7290
# Epoch [2/100], Training Loss: 25900.8611, LR: 0.009990
# Validation Loss: 12711.8353
# Epoch [3/100], Training Loss: 24977.0735, LR: 0.009978
# Validation Loss: 12438.3563
# Saved best model with validation loss: 12438.3563
# Epoch [4/100], Training Loss: 24792.0817, LR: 0.009961
# Validation Loss: 12444.6151
# Epoch [5/100], Training Loss: 24373.9152, LR: 0.009938
# Validation Loss: 11929.5745
# Saved best model with validation loss: 11929.5745
# Epoch [6/100], Training Loss: 24193.0467, LR: 0.009911
# Validation Loss: 11759.1539
# Saved best model with validation loss: 11759.1539
# Epoch [7/100], Training Loss: 23599.8140, LR: 0.009880
# Validation Loss: 11466.2200
# Saved best model with validation loss: 11466.2200
# Epoch [8/100], Training Loss: 23729.0354, LR: 0.009843
# Validation Loss: 11192.2656
# Saved best model with validation loss: 11192.2656
# Epoch [9/100], Training Loss: 23006.7135, LR: 0.009801
# Validation Loss: 11470.3214
# Epoch [10/100], Training Loss: 23192.0386, LR: 0.009755
# Validation Loss: 11406.6440
# Epoch [11/100], Training Loss: 23015.8383, LR: 0.009704
# Validation Loss: 11752.6890
# Epoch [12/100], Training Loss: 22893.7324, LR: 0.009649
# Validation Loss: 11266.8967
# Epoch [13/100], Training Loss: 22766.2071, LR: 0.009589
# Validation Loss: 11574.0742
# Epoch [14/100], Training Loss: 22792.6314, LR: 0.009524
# Validation Loss: 11690.0005
# Epoch [15/100], Training Loss: 22763.6972, LR: 0.009455
# Validation Loss: 11273.2386
# Epoch [16/100], Training Loss: 22853.5042, LR: 0.009382
# Validation Loss: 12199.5479
# Epoch [17/100], Training Loss: 22746.3650, LR: 0.009304
# Validation Loss: 11464.4896
# Epoch [18/100], Training Loss: 22671.5544, LR: 0.009222
# Validation Loss: 11820.8350
# Epoch [19/100], Training Loss: 22487.9072, LR: 0.009135
# Validation Loss: 13482.3981
# Epoch [20/100], Training Loss: 22535.3938, LR: 0.009045
# Validation Loss: 13370.6939
# Epoch [21/100], Training Loss: 22642.4876, LR: 0.008951
# Validation Loss: 11605.4432
# Epoch [22/100], Training Loss: 22551.5813, LR: 0.008853
# Validation Loss: 12525.5043
# Epoch [23/100], Training Loss: 22467.1984, LR: 0.008751
# Validation Loss: 13260.9611
# Epoch [24/100], Training Loss: 22824.9883, LR: 0.008645
# Validation Loss: 12009.3351
# Epoch [25/100], Training Loss: 22495.4415, LR: 0.008536
# Validation Loss: 12658.5147
# Epoch [26/100], Training Loss: 22353.0297, LR: 0.008423
# Validation Loss: 11739.9430
# Epoch [27/100], Training Loss: 22581.7508, LR: 0.008307
# Validation Loss: 11644.2125
# Epoch [28/100], Training Loss: 22386.0037, LR: 0.008187
# Validation Loss: 12052.3768
# Epoch [29/100], Training Loss: 22438.1251, LR: 0.008065
# Validation Loss: 12295.6173
# Epoch [30/100], Training Loss: 22361.2736, LR: 0.007939
# Validation Loss: 11841.7319
# Epoch [31/100], Training Loss: 22372.2771, LR: 0.007810
# Validation Loss: 11806.1955
# Epoch [32/100], Training Loss: 22470.7081, LR: 0.007679
# Validation Loss: 12616.7032
# Epoch [33/100], Training Loss: 22322.1501, LR: 0.007545
# Validation Loss: 12849.9157
# Epoch [34/100], Training Loss: 22671.5388, LR: 0.007409
# Validation Loss: 12206.7558
# Epoch [35/100], Training Loss: 22868.1502, LR: 0.007270
# Validation Loss: 12021.2213
# Epoch [36/100], Training Loss: 22565.4404, LR: 0.007129
# Validation Loss: 16123.2708
# Epoch [37/100], Training Loss: 22349.5818, LR: 0.006986
# Validation Loss: 14689.7303
# Epoch [38/100], Training Loss: 22130.4096, LR: 0.006841
# Validation Loss: 11805.7498
# Epoch [39/100], Training Loss: 22244.1155, LR: 0.006694
# Validation Loss: 11791.8664
# Epoch [40/100], Training Loss: 22221.6872, LR: 0.006545
# Validation Loss: 12668.4964
# Epoch [41/100], Training Loss: 22445.4308, LR: 0.006395
# Validation Loss: 13240.8783
# Epoch [42/100], Training Loss: 22213.0266, LR: 0.006243
# Validation Loss: 14519.2494
# Epoch [43/100], Training Loss: 22448.3215, LR: 0.006091
# Validation Loss: 12496.4975
# Epoch [44/100], Training Loss: 22331.8398, LR: 0.005937
# Validation Loss: 11861.1813
# Epoch [45/100], Training Loss: 22177.4286, LR: 0.005782
# Validation Loss: 14112.5699
# Epoch [46/100], Training Loss: 22529.9505, LR: 0.005627
# Validation Loss: 11896.5325
# Epoch [47/100], Training Loss: 22374.3168, LR: 0.005471
# Validation Loss: 11871.2201
# Epoch [48/100], Training Loss: 22250.6303, LR: 0.005314
# Validation Loss: 11419.1351
# Epoch [49/100], Training Loss: 22100.8795, LR: 0.005157
# Validation Loss: 11210.9803
# Epoch [50/100], Training Loss: 22507.9419, LR: 0.005000
# Validation Loss: 11480.9735
# Epoch [51/100], Training Loss: 22105.1444, LR: 0.004843
# Validation Loss: 11163.9815
# Saved best model with validation loss: 11163.9815
# Epoch [52/100], Training Loss: 22095.8109, LR: 0.004686
# Validation Loss: 11163.4588
# Saved best model with validation loss: 11163.4588
# Epoch [53/100], Training Loss: 22197.9914, LR: 0.004529
# Validation Loss: 11097.6430
# Saved best model with validation loss: 11097.6430
# Epoch [54/100], Training Loss: 22262.1918, LR: 0.004373
# Validation Loss: 11326.4689
# Epoch [55/100], Training Loss: 22097.2329, LR: 0.004218
# Validation Loss: 11320.8801
# Epoch [56/100], Training Loss: 22185.9569, LR: 0.004063
# Validation Loss: 11155.4260
# Epoch [57/100], Training Loss: 21976.1047, LR: 0.003909
# Validation Loss: 11613.1973
# Epoch [58/100], Training Loss: 22027.7651, LR: 0.003757
# Validation Loss: 11260.1262
# Epoch [59/100], Training Loss: 22153.1796, LR: 0.003605
# Validation Loss: 11168.4885
# Epoch [60/100], Training Loss: 21977.0601, LR: 0.003455
# Validation Loss: 11139.5283
# Epoch [61/100], Training Loss: 22011.9262, LR: 0.003306
# Validation Loss: 11356.0265
# Epoch [62/100], Training Loss: 22449.7278, LR: 0.003159
# Validation Loss: 11270.7857
# Epoch [63/100], Training Loss: 21979.2854, LR: 0.003014
# Validation Loss: 11179.7778
# Epoch [64/100], Training Loss: 22036.3227, LR: 0.002871
# Validation Loss: 11331.0011
# Epoch [65/100], Training Loss: 22153.5423, LR: 0.002730
# Validation Loss: 11173.5513
# Epoch [66/100], Training Loss: 21976.9530, LR: 0.002591
# Validation Loss: 11223.3371
# Epoch [67/100], Training Loss: 22012.5737, LR: 0.002455
# Validation Loss: 11330.2590
# Epoch [68/100], Training Loss: 22093.1673, LR: 0.002321
# Validation Loss: 11061.5183
# Saved best model with validation loss: 11061.5183
# Epoch [69/100], Training Loss: 21896.6832, LR: 0.002190
# Validation Loss: 11022.0658
# Saved best model with validation loss: 11022.0658
# Epoch [70/100], Training Loss: 22092.4297, LR: 0.002061
# Validation Loss: 11131.8795
# Epoch [71/100], Training Loss: 22220.9153, LR: 0.001935
# Validation Loss: 11350.9745
# Epoch [72/100], Training Loss: 22121.1364, LR: 0.001813
# Validation Loss: 11222.4093
# Epoch [73/100], Training Loss: 21869.7895, LR: 0.001693
# Validation Loss: 11169.9926
# Epoch [74/100], Training Loss: 22430.3499, LR: 0.001577
# Validation Loss: 11236.1255
# Epoch [75/100], Training Loss: 23312.5710, LR: 0.001464
# Validation Loss: 11189.2019
# Epoch [76/100], Training Loss: 22411.0573, LR: 0.001355
# Validation Loss: 11003.7674
# Saved best model with validation loss: 11003.7674
# Epoch [77/100], Training Loss: 22500.2296, LR: 0.001249
# Validation Loss: 10981.1973
# Saved best model with validation loss: 10981.1973
# Epoch [78/100], Training Loss: 21915.6816, LR: 0.001147
# Validation Loss: 11075.7455
# Epoch [79/100], Training Loss: 21829.2535, LR: 0.001049
# Validation Loss: 11110.3016
# Epoch [80/100], Training Loss: 22207.0311, LR: 0.000955
# Validation Loss: 11121.7915
# Epoch [81/100], Training Loss: 22039.8415, LR: 0.000865
# Validation Loss: 11217.2150
# Epoch [82/100], Training Loss: 22098.7786, LR: 0.000778
# Validation Loss: 11101.4095
# Epoch [83/100], Training Loss: 21791.4073, LR: 0.000696
# Validation Loss: 11054.0712
# Epoch [84/100], Training Loss: 21826.9606, LR: 0.000618
# Validation Loss: 11094.6651
# Epoch [85/100], Training Loss: 22102.0309, LR: 0.000545
# Validation Loss: 11115.2881
# Epoch [86/100], Training Loss: 21933.3426, LR: 0.000476
# Validation Loss: 11240.7252
# Epoch [87/100], Training Loss: 22168.6233, LR: 0.000411
# Validation Loss: 11169.1762
# Epoch [88/100], Training Loss: 21809.1551, LR: 0.000351
# Validation Loss: 11187.4721
# Epoch [89/100], Training Loss: 21969.3244, LR: 0.000296
# Validation Loss: 11238.5107
# Epoch [90/100], Training Loss: 21867.2083, LR: 0.000245
# Validation Loss: 11195.4816
# Epoch [91/100], Training Loss: 21826.6861, LR: 0.000199
# Validation Loss: 11208.0636
# Epoch [92/100], Training Loss: 21752.7972, LR: 0.000157
# Validation Loss: 11189.3803
# Epoch [93/100], Training Loss: 21931.7967, LR: 0.000120
# Validation Loss: 11196.0960
# Epoch [94/100], Training Loss: 21849.3476, LR: 0.000089
# Validation Loss: 11209.3822
# Epoch [95/100], Training Loss: 22113.4659, LR: 0.000062
# Validation Loss: 11204.4397
# Epoch [96/100], Training Loss: 22030.7184, LR: 0.000039
# Validation Loss: 11202.9770
# Epoch [97/100], Training Loss: 22088.6114, LR: 0.000022
# Validation Loss: 11207.8736
# Epoch [98/100], Training Loss: 22092.8405, LR: 0.000010
# Validation Loss: 11207.5838
# Epoch [99/100], Training Loss: 22048.2989, LR: 0.000002
# Validation Loss: 11209.4927
# Epoch [100/100], Training Loss: 21788.5078, LR: 0.000000
# Validation Loss: 11209.8665
# Training complete. Best validation loss: 10981.1973. Model saved to best_transformer_model.pth.

# %%
def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss_curves(train_losses, val_losses)

# %%
from metrics import (
    compute_predicted_positions,
    compute_mean_ade,
    compute_fde,
    compute_directional_accuracy,
    compute_linear_wade,
    compute_exponential_wade
) # add new imports here as new metrics created

x = torch.tensor(X_val, dtype=torch.float32).to("cuda")
y = torch.tensor(y_val, dtype=torch.float32).to("cuda")
# Compute metrics
with torch.no_grad():
    pred_position = compute_predicted_positions(model, x, y)
    mean_ade = compute_mean_ade(pred_position, y)
    fde = compute_fde(pred_position, y)
    directional_accuracy = compute_directional_accuracy(pred_position, y)
    l_wade = compute_linear_wade(pred_position, y)
    
    alpha = 0.5 #Smaller alpha -> more uniform weights, larger alpha -> more emphasis on earlier timesteps (defaults to 0.1)
    e_wade = compute_exponential_wade(pred_position, y, alpha=alpha) 

print(f"Mean Average Displacement Error (MADE): {mean_ade:.4f}")
print(f"Final Displacement Error (FDE): {fde:.4f}")
print(f"Directional Accuracy (DA): {directional_accuracy:.4f}")
print(f"Linear Weighted Average Displacement Error (LWADE): {l_wade:.4f}")
print(f"Exponential Weighted Average Displacement Error (EWADE) with alpha={alpha}: {e_wade:.4f}")
print(f"Overall Score (Lower is better) = {e_wade + 0.5 * fde - 0.5 * directional_accuracy}")
# Out:
# Mean Average Displacement Error (MADE): 4.6683
# Final Displacement Error (FDE): 10.3321
# Directional Accuracy (DA): 0.3344
# Linear Weighted Average Displacement Error (LWADE): 0.3224
# Exponential Weighted Average Displacement Error (EWADE) with alpha=0.5: 0.2015
# Overall Score (Lower is better) = 5.20037043094635

# %%
 # Example 400 - straight path towards top right
example_index = 400
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 369 - very slight curve
example_index = 369
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 411 - straight path towards bottom left
example_index = 411
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 31 - No movement
example_index = 31
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 291 - Sharp turn
example_index = 291
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 370 - Smooth slight turn
example_index = 370
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 77 - smooth 90 degree turn
example_index = 77
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()
