# %%
import numpy as np
import pickle

import torch
from torch import nn
import torch.nn.functional as F

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
run_local = True # change to False if using google drive
from enum import Enum

if run_local: # place pickle file in same directory as this ipynb
    data_path = 'parsed_data_final_srishti.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)
else:
    from google.colab import drive
    drive.mount('/content/drive')
    data_path = '/content/drive/MyDrive/CS7643Group/Dataset/parsed_data_final_srishti.pkl'
    with open(data_path, "rb") as file:
        data = pickle.load(file)

print(f"Shape of full dataset: {data.shape}")
data = data[:, :-1, :]


class FeatureOption(Enum):
    VEHICLE_ONLY = 1 # Vehicle features only
    VEHICLE_AND_PEDESTRIAN = 2 # Vehicle and Pedestrian features:
    VEHICLE_PEDESTRIAN_ROADGRAPH = 3 # Vehicle and Pedestrian and Roadgraph features:
    VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE = 4 # Vehicle and Pedestrian and Roadgraph and Bicycle features

feature_option = FeatureOption.VEHICLE_ONLY # choose from: VEHICLE_ONLY, VEHICLE_AND_PEDESTRIAN, VEHICLE_PEDESTRIAN_ROADGRAPH, VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE

if feature_option == FeatureOption.VEHICLE_ONLY: # Vehicle Only
    data = data[:, :, 1:6]
elif feature_option == FeatureOption.VEHICLE_AND_PEDESTRIAN: # Vehicle and pedestrian
    data = data[:, :, 1:8]
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH: # Vehicle, pedestrian, and roadgraph 
    vehicle_pedestrian = data[:, :, 1:8]
    roadgraph = data[:, :, 10:]
    data = np.concatenate((vehicle_pedestrian, roadgraph), axis = 2)
elif feature_option == FeatureOption.VEHICLE_PEDESTRIAN_ROADGRAPH_AND_BICYCLE: # vehicle, pedestrian, roadgraph and bicycle
    data = data[:, :, 1:]
else:
    raise Exception("Invalid Choice")


first_set = data[:, :, :-2]
last_two_values = data[:, :, -2:]

# Compute min and max for the last two features
min_val_last_two = last_two_values.min(axis=(0, 1), keepdims=True)  # Shape: (1, 1, 2)
max_val_last_two = last_two_values.max(axis=(0, 1), keepdims=True)  # Shape: (1, 1, 2)

# Normalize the last two values using their specific min and max
normalized_last_two = (last_two_values - min_val_last_two) / (max_val_last_two - min_val_last_two + 1e-8)

# Update the data with normalized last two features
data[:, :, -2:] = normalized_last_two


X_train = data[:int(0.8*len(data)), :80, :]
X_val = data[int(0.8*len(data)): , :80, :]

y_train = data[:int(0.8*len(data)), 80:, :]
y_val = data[int(0.8*len(data)): , 80:, :]

print("For each input state: X position, Y position, X velocity, Y velocity, Heading")
print("For each output state: X velocity, Y velocity")
print("Feature Type: ", feature_option)
print("\nTraining Data:")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")

print("\nValidation Data:") 
print(f"X_val shape: {X_val.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# Shape of full dataset: (2933, 91, 14)
# For each input state: X position, Y position, X velocity, Y velocity, Heading
# For each output state: X velocity, Y velocity
# Feature Type:  FeatureOption.VEHICLE_ONLY
#
# Training Data:
# X_train shape: (2346, 80, 5)
# y_train shape: (2346, 10, 5)
#
# Validation Data:
# X_val shape: (587, 80, 5)
# y_val shape: (587, 10, 5)

# %%
import torch
import torch.nn as nn

class TrajectoryTransformer(nn.Module):
    def __init__(self, input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10, max_seq_length=100):
        super(TrajectoryTransformer, self).__init__()
        self.embedding = nn.Linear(input_size, model_dim)
        self.positional_encoding = nn.Parameter(torch.randn(max_seq_length, model_dim))
        self.transformer = nn.Transformer(
            d_model=model_dim,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            num_decoder_layers=num_layers,
            dim_feedforward=4 * model_dim,
            dropout=0.5 #dropout=0.1
        )
        self.fc = nn.Linear(model_dim, output_features * output_timesteps)
        self.output_features = output_features
        self.output_timesteps = output_timesteps

    def forward(self, x):
        # x: (batch_size, seq_length, input_size)
        batch_size, seq_length, input_size = x.size()
        src = self.embedding(x) + self.positional_encoding[:seq_length]  # Add positional encoding
        src = src.permute(1, 0, 2)  # Transformer expects (seq_len, batch_size, model_dim)

        tgt = torch.zeros_like(src)  # Dummy target (for autoregressive tasks, replace with actual decoder inputs if needed)

        # Pass through the Transformer
        output = self.transformer(src, tgt)
        output = output[-1]  # Take the last sequence position
        output = self.fc(output)
        return output.view(-1, self.output_timesteps, self.output_features)  # Reshape to (batch_size, 10, 2)

# %%
import torch
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from loss_functions import get_loss_function

# Initialize lists to store loss history
train_losses = []
val_losses = []

def train_model(model, train_loader, val_loader, num_epochs=10, initial_lr=0.001, T_max=10, loss_fn=nn.MSELoss()):
    optimizer = optim.Adam(model.parameters(), lr=initial_lr)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=T_max)

    best_val_loss = float('inf')
    model_save_path = "transformer_external_model.pth"  # Save path for the best model

    for epoch in range(num_epochs):
        # Training loop
        model.train()
        epoch_train_loss = 0
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")

            optimizer.zero_grad()
            predictions = model(batch_x)
            # print(predictions.shape)
            loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_train_loss += loss.item()

        scheduler.step()

        avg_train_loss = epoch_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)
        print(f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}')

        # Validation loop
        model.eval()
        epoch_val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
                predictions = model(batch_x)
                loss = loss_fn(predictions, batch_y, batch_x[:, 0, :2])
                epoch_val_loss += loss.item()

            avg_val_loss = epoch_val_loss / len(val_loader)
            val_losses.append(avg_val_loss)
            print(f'Validation Loss: {avg_val_loss:.4f}')

            # Save the model if it has the best validation loss (Comment out if you don't want to save)
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(model.state_dict(), model_save_path)
                print(f"Saved best model with validation loss: {best_val_loss:.4f}")

    print(f"Training complete. Best validation loss: {best_val_loss:.4f}. Model saved to {model_save_path}.")


train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(y_val, dtype=torch.float32))
# Mess with batch size here
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)


input_size = X_train.shape[2]
# print(input_size)
hidden_size = 64 # changeable
input_size = X_train.shape[2]

model_dim = 16  # Adjustable
num_heads = 1  # Adjustable
num_layers = 1  # Adjustable

model = TrajectoryTransformer(input_size, model_dim, num_heads, num_layers, output_features=2, output_timesteps=10).to("cuda")

loss_weights = { # Update weights of different loss terms 
    "position_loss": 1.0,
    "velocity_loss": 0.5,
    "smoothness_loss": 0.25,
    "terminal_loss": 2.0,
    "delta_loss": 0.5
}
# Customize loss function here (Everything is True/False except time_weighting_scheme)
loss_fn = get_loss_function(
    "trajectory_loss", # trajectory_loss is just position loss if everything else is False
    use_velocity_loss=True,
    use_smoothness_loss=True,
    use_terminal_loss=True,
    time_weighting_scheme='Exponential',  #None, Linear, Exponential
    use_delta_loss=True,
    prediction_horizon=10, # change to match predicted timesteps (used for time)
    loss_weights=loss_weights # defaults to ALL = 1.0 if not included
) # Add more lines as new loss functions are added

# mess with epochs, initial_lr and T_max here
train_model(model, train_loader, val_loader, num_epochs=100, initial_lr=1e-2, T_max=100, loss_fn=loss_fn)
# Out:
# c:\Users\rsudu\mambaforge\envs\cv_proj5\lib\site-packages\torch\nn\modules\transformer.py:379: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Epoch [1/100], Training Loss: 26749.9925, LR: 0.009998
# Validation Loss: 12771.4103
# Saved best model with validation loss: 12771.4103
# Epoch [2/100], Training Loss: 25612.7708, LR: 0.009990
# Validation Loss: 11814.2154
# Saved best model with validation loss: 11814.2154
# Epoch [3/100], Training Loss: 24464.1651, LR: 0.009978
# Validation Loss: 11511.8863
# Saved best model with validation loss: 11511.8863
# Epoch [4/100], Training Loss: 23979.9273, LR: 0.009961
# Validation Loss: 11675.3743
# Epoch [5/100], Training Loss: 23701.8234, LR: 0.009938
# Validation Loss: 11669.6002
# Epoch [6/100], Training Loss: 23723.3587, LR: 0.009911
# Validation Loss: 11554.1929
# Epoch [7/100], Training Loss: 23750.2232, LR: 0.009880
# Validation Loss: 12033.5030
# Epoch [8/100], Training Loss: 23312.2203, LR: 0.009843
# Validation Loss: 11551.8124
# Epoch [9/100], Training Loss: 23280.0845, LR: 0.009801
# Validation Loss: 12117.0837
# Epoch [10/100], Training Loss: 23387.9418, LR: 0.009755
# Validation Loss: 11587.5586
# Epoch [11/100], Training Loss: 23435.6806, LR: 0.009704
# Validation Loss: 11683.7562
# Epoch [12/100], Training Loss: 23129.5673, LR: 0.009649
# Validation Loss: 12175.1463
# Epoch [13/100], Training Loss: 23170.9979, LR: 0.009589
# Validation Loss: 11909.8911
# Epoch [14/100], Training Loss: 22999.1439, LR: 0.009524
# Validation Loss: 12188.7663
# Epoch [15/100], Training Loss: 22938.5769, LR: 0.009455
# Validation Loss: 11791.7128
# Epoch [16/100], Training Loss: 23272.7065, LR: 0.009382
# Validation Loss: 11701.0146
# Epoch [17/100], Training Loss: 23538.7729, LR: 0.009304
# Validation Loss: 11607.3317
# Epoch [18/100], Training Loss: 23123.9419, LR: 0.009222
# Validation Loss: 12148.0630
# Epoch [19/100], Training Loss: 23037.7842, LR: 0.009135
# Validation Loss: 11443.1195
# Saved best model with validation loss: 11443.1195
# Epoch [20/100], Training Loss: 23066.4367, LR: 0.009045
# Validation Loss: 11463.5638
# Epoch [21/100], Training Loss: 23218.3180, LR: 0.008951
# Validation Loss: 11685.0177
# Epoch [22/100], Training Loss: 22983.5698, LR: 0.008853
# Validation Loss: 11753.1846
# Epoch [23/100], Training Loss: 23015.4331, LR: 0.008751
# Validation Loss: 11415.9624
# Saved best model with validation loss: 11415.9624
# Epoch [24/100], Training Loss: 22751.8106, LR: 0.008645
# Validation Loss: 11227.5757
# Saved best model with validation loss: 11227.5757
# Epoch [25/100], Training Loss: 22795.0661, LR: 0.008536
# Validation Loss: 11477.5475
# Epoch [26/100], Training Loss: 22760.5951, LR: 0.008423
# Validation Loss: 11566.4000
# Epoch [27/100], Training Loss: 23100.9293, LR: 0.008307
# Validation Loss: 11342.9292
# Epoch [28/100], Training Loss: 23156.6653, LR: 0.008187
# Validation Loss: 11633.7274
# Epoch [29/100], Training Loss: 23261.0429, LR: 0.008065
# Validation Loss: 11570.4085
# Epoch [30/100], Training Loss: 23110.5621, LR: 0.007939
# Validation Loss: 11501.2492
# Epoch [31/100], Training Loss: 22900.0368, LR: 0.007810
# Validation Loss: 11406.6420
# Epoch [32/100], Training Loss: 22768.7669, LR: 0.007679
# Validation Loss: 11648.7102
# Epoch [33/100], Training Loss: 23031.9190, LR: 0.007545
# Validation Loss: 11596.4250
# Epoch [34/100], Training Loss: 23052.9260, LR: 0.007409
# Validation Loss: 11436.4874
# Epoch [35/100], Training Loss: 22807.2864, LR: 0.007270
# Validation Loss: 11379.9045
# Epoch [36/100], Training Loss: 22797.5107, LR: 0.007129
# Validation Loss: 12375.9236
# Epoch [37/100], Training Loss: 23119.3691, LR: 0.006986
# Validation Loss: 11967.3149
# Epoch [38/100], Training Loss: 22856.3330, LR: 0.006841
# Validation Loss: 12637.9522
# Epoch [39/100], Training Loss: 22944.6091, LR: 0.006694
# Validation Loss: 12644.1053
# Epoch [40/100], Training Loss: 22884.4055, LR: 0.006545
# Validation Loss: 12539.6139
# Epoch [41/100], Training Loss: 22569.1108, LR: 0.006395
# Validation Loss: 12190.0004
# Epoch [42/100], Training Loss: 22874.0199, LR: 0.006243
# Validation Loss: 11789.7023
# Epoch [43/100], Training Loss: 22706.6646, LR: 0.006091
# Validation Loss: 11802.3520
# Epoch [44/100], Training Loss: 22790.6116, LR: 0.005937
# Validation Loss: 11780.0389
# Epoch [45/100], Training Loss: 23036.0208, LR: 0.005782
# Validation Loss: 11961.9688
# Epoch [46/100], Training Loss: 23127.3457, LR: 0.005627
# Validation Loss: 11636.6412
# Epoch [47/100], Training Loss: 22957.4969, LR: 0.005471
# Validation Loss: 11457.0070
# Epoch [48/100], Training Loss: 23508.7401, LR: 0.005314
# Validation Loss: 11451.8131
# Epoch [49/100], Training Loss: 23002.4601, LR: 0.005157
# Validation Loss: 11352.0755
# Epoch [50/100], Training Loss: 22854.3416, LR: 0.005000
# Validation Loss: 11641.2475
# Epoch [51/100], Training Loss: 22494.1885, LR: 0.004843
# Validation Loss: 11592.3760
# Epoch [52/100], Training Loss: 23008.7305, LR: 0.004686
# Validation Loss: 12080.0815
# Epoch [53/100], Training Loss: 22660.8996, LR: 0.004529
# Validation Loss: 11868.3135
# Epoch [54/100], Training Loss: 22624.4862, LR: 0.004373
# Validation Loss: 11663.3713
# Epoch [55/100], Training Loss: 22787.5272, LR: 0.004218
# Validation Loss: 11575.1645
# Epoch [56/100], Training Loss: 23369.9923, LR: 0.004063
# Validation Loss: 11653.4222
# Epoch [57/100], Training Loss: 22571.0752, LR: 0.003909
# Validation Loss: 11466.5734
# Epoch [58/100], Training Loss: 22689.0003, LR: 0.003757
# Validation Loss: 11379.0238
# Epoch [59/100], Training Loss: 22697.5160, LR: 0.003605
# Validation Loss: 11340.5324
# Epoch [60/100], Training Loss: 22560.2362, LR: 0.003455
# Validation Loss: 11565.6686
# Epoch [61/100], Training Loss: 22746.3907, LR: 0.003306
# Validation Loss: 11429.9628
# Epoch [62/100], Training Loss: 22510.7925, LR: 0.003159
# Validation Loss: 11402.0720
# Epoch [63/100], Training Loss: 22515.1539, LR: 0.003014
# Validation Loss: 11413.7609
# Epoch [64/100], Training Loss: 22680.3298, LR: 0.002871
# Validation Loss: 11331.0186
# Epoch [65/100], Training Loss: 22559.6107, LR: 0.002730
# Validation Loss: 12224.3875
# Epoch [66/100], Training Loss: 22501.0811, LR: 0.002591
# Validation Loss: 12189.8350
# Epoch [67/100], Training Loss: 22594.3473, LR: 0.002455
# Validation Loss: 11738.9378
# Epoch [68/100], Training Loss: 22452.9754, LR: 0.002321
# Validation Loss: 11719.3206
# Epoch [69/100], Training Loss: 22469.3959, LR: 0.002190
# Validation Loss: 11829.0998
# Epoch [70/100], Training Loss: 22663.8353, LR: 0.002061
# Validation Loss: 11936.7390
# Epoch [71/100], Training Loss: 22616.2489, LR: 0.001935
# Validation Loss: 11597.1849
# Epoch [72/100], Training Loss: 22691.9940, LR: 0.001813
# Validation Loss: 11263.6734
# Epoch [73/100], Training Loss: 22636.3432, LR: 0.001693
# Validation Loss: 11456.6802
# Epoch [74/100], Training Loss: 22818.3940, LR: 0.001577
# Validation Loss: 11469.3773
# Epoch [75/100], Training Loss: 22826.6831, LR: 0.001464
# Validation Loss: 11318.9113
# Epoch [76/100], Training Loss: 22624.8705, LR: 0.001355
# Validation Loss: 11304.0869
# Epoch [77/100], Training Loss: 22817.8066, LR: 0.001249
# Validation Loss: 11212.1099
# Saved best model with validation loss: 11212.1099
# Epoch [78/100], Training Loss: 22577.5365, LR: 0.001147
# Validation Loss: 11228.4144
# Epoch [79/100], Training Loss: 22478.7860, LR: 0.001049
# Validation Loss: 11198.9154
# Saved best model with validation loss: 11198.9154
# Epoch [80/100], Training Loss: 22474.5351, LR: 0.000955
# Validation Loss: 11185.4879
# Saved best model with validation loss: 11185.4879
# Epoch [81/100], Training Loss: 22471.6095, LR: 0.000865
# Validation Loss: 11229.5680
# Epoch [82/100], Training Loss: 22514.1554, LR: 0.000778
# Validation Loss: 11232.6353
# Epoch [83/100], Training Loss: 22701.0090, LR: 0.000696
# Validation Loss: 11199.2349
# Epoch [84/100], Training Loss: 22853.1094, LR: 0.000618
# Validation Loss: 11210.0650
# Epoch [85/100], Training Loss: 22464.0754, LR: 0.000545
# Validation Loss: 11207.1133
# Epoch [86/100], Training Loss: 22454.4026, LR: 0.000476
# Validation Loss: 11199.7815
# Epoch [87/100], Training Loss: 22694.4570, LR: 0.000411
# Validation Loss: 11189.4274
# Epoch [88/100], Training Loss: 22653.9015, LR: 0.000351
# Validation Loss: 11177.4423
# Saved best model with validation loss: 11177.4423
# Epoch [89/100], Training Loss: 22940.5182, LR: 0.000296
# Validation Loss: 11212.4825
# Epoch [90/100], Training Loss: 22712.1256, LR: 0.000245
# Validation Loss: 11225.1802
# Epoch [91/100], Training Loss: 22503.5889, LR: 0.000199
# Validation Loss: 11202.1774
# Epoch [92/100], Training Loss: 22783.6365, LR: 0.000157
# Validation Loss: 11202.8512
# Epoch [93/100], Training Loss: 22842.0990, LR: 0.000120
# Validation Loss: 11191.6788
# Epoch [94/100], Training Loss: 22609.0383, LR: 0.000089
# Validation Loss: 11214.7981
# Epoch [95/100], Training Loss: 22835.5144, LR: 0.000062
# Validation Loss: 11207.9794
# Epoch [96/100], Training Loss: 22488.4165, LR: 0.000039
# Validation Loss: 11201.1687
# Epoch [97/100], Training Loss: 22723.1574, LR: 0.000022
# Validation Loss: 11199.9945
# Epoch [98/100], Training Loss: 22545.8778, LR: 0.000010
# Validation Loss: 11197.9445
# Epoch [99/100], Training Loss: 22557.3223, LR: 0.000002
# Validation Loss: 11197.8019
# Epoch [100/100], Training Loss: 22467.3536, LR: 0.000000
# Validation Loss: 11198.0207
# Training complete. Best validation loss: 11177.4423. Model saved to transformer_external_model.pth.

# %%
def plot_loss_curves(train_losses, val_losses):
    plt.figure(figsize=(8, 4))
    plt.plot(train_losses, label='Training Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='orange')
    plt.title('Training and Validation Loss Curves')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

plot_loss_curves(train_losses, val_losses)

# %%
from metrics import (
    compute_predicted_positions,
    compute_mean_ade,
    compute_fde,
    compute_directional_accuracy,
    compute_linear_wade,
    compute_exponential_wade
) # add new imports here as new metrics created

x = torch.tensor(X_val, dtype=torch.float32).to("cuda")
y = torch.tensor(y_val, dtype=torch.float32).to("cuda")
# Compute metrics
with torch.no_grad():
    pred_position = compute_predicted_positions(model, x, y)
    mean_ade = compute_mean_ade(pred_position, y)
    fde = compute_fde(pred_position, y)
    directional_accuracy = compute_directional_accuracy(pred_position, y)
    l_wade = compute_linear_wade(pred_position, y)
    
    alpha = 0.5 #Smaller alpha -> more uniform weights, larger alpha -> more emphasis on earlier timesteps (defaults to 0.1)
    e_wade = compute_exponential_wade(pred_position, y, alpha=alpha) 

print(f"Mean Average Displacement Error (MADE): {mean_ade:.4f}")
print(f"Final Displacement Error (FDE): {fde:.4f}")
print(f"Directional Accuracy (DA): {directional_accuracy:.4f}")
print(f"Linear Weighted Average Displacement Error (LWADE): {l_wade:.4f}")
print(f"Exponential Weighted Average Displacement Error (EWADE) with alpha={alpha}: {e_wade:.4f}")
print(f"Overall Score (Lower is better) = {e_wade + 0.5 * fde - 0.5 * directional_accuracy}")
# Out:
# Mean Average Displacement Error (MADE): 3.3478
# Final Displacement Error (FDE): 7.5935
# Directional Accuracy (DA): 0.3456
# Linear Weighted Average Displacement Error (LWADE): 0.2290
# Exponential Weighted Average Displacement Error (EWADE) with alpha=0.5: 0.1431
# Overall Score (Lower is better) = 3.7670395374298096

# %%
# Example 400 - straight path towards top right
example_index = 400
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 369 - very slight curve
example_index = 369
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 411 - straight path towards bottom left
example_index = 411
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 31 - No movement
example_index = 31
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 291 - Sharp turn
example_index = 291
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 370 - Smooth slight turn
example_index = 370
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()

# Example 77 - smooth 90 degree turn
example_index = 77
past_traj = X_val[example_index]
future_traj = y_val[example_index]

# Get the predicted future trajectory
with torch.no_grad():
  model.eval()
  X = torch.tensor(past_traj[np.newaxis, :, :], dtype=torch.float32).to("cuda")
  predicted_vels = model(X)

  predicted_vels = predicted_vels[0]
  cum_disp = torch.cumsum(predicted_vels * 0.1, dim=1)
  future_pred = cum_disp + X[0, -1, :2]
  future_pred = future_pred.cpu().numpy()

# Plot the trajectory
plt.figure(figsize=(6, 6))
plt.plot(past_traj[:, 0], past_traj[:, 1], label='Past Trajectory', color='blue')
plt.plot(future_traj[:, 0], future_traj[:, 1], label='Actual Future Trajectory', color='red')
plt.plot(future_pred[:, 0], future_pred[:, 1], label='Predicted Future Trajectory', color='green')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.title(f"Predicted vs. Actual Future Trajectory (Example {example_index})")
plt.axis('equal')
plt.legend()
plt.grid()
plt.show()
